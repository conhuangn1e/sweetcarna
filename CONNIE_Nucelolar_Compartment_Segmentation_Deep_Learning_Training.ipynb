# %% [markdown]
# <a href="https://colab.research.google.com/github/conhuangn1e/sweetcarna/blob/main/CONNIE_Nucelolar_Compartment_Segmentation_Deep_Learning_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ####Author: Hana Jaafari
# ####Date: January 30, 2025
# ####Purpose: The objective of this code is to train on high-resolution fluorescent images of NPM1 protein and "learn" the multiple compartments of the nucleolus (the known three or even more). With this segmentation and using fluorescent images of other nucleolar proteins, we can try to learn the concentrations (and consequently other physical properties) of the other nucleolar proteins.

# %%
import os
import matplotlib.pylab as plt
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision
import torch.nn as nn
import torch.optim as optim
import glob
import time
from skimage import io, transform
from imutils import paths
from tqdm import tqdm

import itertools
import pandas as pd
import torch
from scipy.ndimage import convolve
from scipy.ndimage import convolve
from torch.utils.data import random_split
import skimage as ski
from sklearn.model_selection import train_test_split

np.random.seed(11) # set seed for reproducibility
torch.random.manual_seed(1)

# %% [markdown]
# Upload Cell_ROI_Images.zip at this point to the files on the left sidebar

# %%
# run this line only once after zip file is uploaded
# !unzip Cell_ROI_Images.zip
# Out:
# Archive:  Cell_ROI_Images.zip
#    creating: Cell_ROI_Images/
#   inflating: __MACOSX/._Cell_ROI_Images
#   inflating: Cell_ROI_Images/ba082356-76fc-409d-9445-4ba55424903a.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._ba082356-76fc-409d-9445-4ba55424903a.tiff
#   inflating: Cell_ROI_Images/._ba082356-76fc-409d-9445-4ba55424903a.tiff
#   inflating: Cell_ROI_Images/058ade94-dbb3-4bde-9539-cf428febbfc1.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._058ade94-dbb3-4bde-9539-cf428febbfc1.tiff
#   inflating: Cell_ROI_Images/._058ade94-dbb3-4bde-9539-cf428febbfc1.tiff
#   inflating: Cell_ROI_Images/fb03d124-a24c-4bce-9591-e5fe11f2bbb3.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._fb03d124-a24c-4bce-9591-e5fe11f2bbb3.tiff
#   inflating: Cell_ROI_Images/._fb03d124-a24c-4bce-9591-e5fe11f2bbb3.tiff
#   inflating: Cell_ROI_Images/20ab104c-dc92-44fa-a67d-c5cf10570b6c.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._20ab104c-dc92-44fa-a67d-c5cf10570b6c.tiff
#   inflating: Cell_ROI_Images/._20ab104c-dc92-44fa-a67d-c5cf10570b6c.tiff
#   inflating: Cell_ROI_Images/bd2b98c0-c231-462c-8e96-d8288d92ff68.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._bd2b98c0-c231-462c-8e96-d8288d92ff68.tiff
#   inflating: Cell_ROI_Images/._bd2b98c0-c231-462c-8e96-d8288d92ff68.tiff
#   inflating: Cell_ROI_Images/8669bbf0-e8e4-4023-b60b-446684ac7f6b.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._8669bbf0-e8e4-4023-b60b-446684ac7f6b.tiff
#   inflating: Cell_ROI_Images/._8669bbf0-e8e4-4023-b60b-446684ac7f6b.tiff
#   inflating: Cell_ROI_Images/f8994c82-d96e-4aca-b760-6b823f07bc8d.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._f8994c82-d96e-4aca-b760-6b823f07bc8d.tiff
#   inflating: Cell_ROI_Images/._f8994c82-d96e-4aca-b760-6b823f07bc8d.tiff
#   inflating: Cell_ROI_Images/8164c096-74f3-41bf-90e3-8f67c112528a.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._8164c096-74f3-41bf-90e3-8f67c112528a.tiff
#   inflating: Cell_ROI_Images/._8164c096-74f3-41bf-90e3-8f67c112528a.tiff
#   inflating: Cell_ROI_Images/559fb601-502c-4467-a7fd-ac9115f7a069.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._559fb601-502c-4467-a7fd-ac9115f7a069.tiff
#   inflating: Cell_ROI_Images/._559fb601-502c-4467-a7fd-ac9115f7a069.tiff
#   inflating: Cell_ROI_Images/44fe3be3-a82d-4880-92cd-ef9ea54ca583.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._44fe3be3-a82d-4880-92cd-ef9ea54ca583.tiff
#   inflating: Cell_ROI_Images/._44fe3be3-a82d-4880-92cd-ef9ea54ca583.tiff
#   inflating: Cell_ROI_Images/10fa7dcb-d4a9-4cca-b57a-6c534fd5b957.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._10fa7dcb-d4a9-4cca-b57a-6c534fd5b957.tiff
#   inflating: Cell_ROI_Images/._10fa7dcb-d4a9-4cca-b57a-6c534fd5b957.tiff
#   inflating: Cell_ROI_Images/5b6e14f7-8523-47dd-a2da-361886b367ae.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._5b6e14f7-8523-47dd-a2da-361886b367ae.tiff
#   inflating: Cell_ROI_Images/._5b6e14f7-8523-47dd-a2da-361886b367ae.tiff
#   inflating: Cell_ROI_Images/29ad3a20-fa51-4e8a-9a49-c494138a0731.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._29ad3a20-fa51-4e8a-9a49-c494138a0731.tiff
#   inflating: Cell_ROI_Images/._29ad3a20-fa51-4e8a-9a49-c494138a0731.tiff
#   inflating: Cell_ROI_Images/cae9d5c0-9393-405d-94a1-4c279a536f31.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._cae9d5c0-9393-405d-94a1-4c279a536f31.tiff
#   inflating: Cell_ROI_Images/._cae9d5c0-9393-405d-94a1-4c279a536f31.tiff
#   inflating: Cell_ROI_Images/697e322d-85b7-4665-9614-56c5ab7a07de.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._697e322d-85b7-4665-9614-56c5ab7a07de.tiff
#   inflating: Cell_ROI_Images/._697e322d-85b7-4665-9614-56c5ab7a07de.tiff
#   inflating: Cell_ROI_Images/0a96a230-2340-4557-846a-bc035d2cc0b5.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._0a96a230-2340-4557-846a-bc035d2cc0b5.tiff
#   inflating: Cell_ROI_Images/._0a96a230-2340-4557-846a-bc035d2cc0b5.tiff
#   inflating: Cell_ROI_Images/98b90999-6755-4576-b8ff-1f17e50fd4d4.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._98b90999-6755-4576-b8ff-1f17e50fd4d4.tiff
#   inflating: Cell_ROI_Images/._98b90999-6755-4576-b8ff-1f17e50fd4d4.tiff
#   inflating: Cell_ROI_Images/0e823be3-179a-4dd8-a822-b788c53cc05c.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._0e823be3-179a-4dd8-a822-b788c53cc05c.tiff
#   inflating: Cell_ROI_Images/._0e823be3-179a-4dd8-a822-b788c53cc05c.tiff
#   inflating: Cell_ROI_Images/6bc7a3dd-a56e-4a20-831d-5b11abd226dc.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._6bc7a3dd-a56e-4a20-831d-5b11abd226dc.tiff
#   inflating: Cell_ROI_Images/._6bc7a3dd-a56e-4a20-831d-5b11abd226dc.tiff
#   inflating: Cell_ROI_Images/a30cc0db-aea5-41b5-94fc-0e66f88d0d0b.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._a30cc0db-aea5-41b5-94fc-0e66f88d0d0b.tiff
#   inflating: Cell_ROI_Images/._a30cc0db-aea5-41b5-94fc-0e66f88d0d0b.tiff
#   inflating: Cell_ROI_Images/e0fc8c19-b1f0-4368-ad3f-da5be813251d.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._e0fc8c19-b1f0-4368-ad3f-da5be813251d.tiff
#   inflating: Cell_ROI_Images/._e0fc8c19-b1f0-4368-ad3f-da5be813251d.tiff
#   inflating: Cell_ROI_Images/ef027af3-e9c1-4571-859d-59aa36fd872e.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._ef027af3-e9c1-4571-859d-59aa36fd872e.tiff
#   inflating: Cell_ROI_Images/._ef027af3-e9c1-4571-859d-59aa36fd872e.tiff
#   inflating: Cell_ROI_Images/95558f4e-8278-40f9-877c-ce01726a7661.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._95558f4e-8278-40f9-877c-ce01726a7661.tiff
#   inflating: Cell_ROI_Images/._95558f4e-8278-40f9-877c-ce01726a7661.tiff
#   inflating: Cell_ROI_Images/88d1a57f-87a2-4fbb-8043-f401d9824295.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._88d1a57f-87a2-4fbb-8043-f401d9824295.tiff
#   inflating: Cell_ROI_Images/._88d1a57f-87a2-4fbb-8043-f401d9824295.tiff
#   inflating: Cell_ROI_Images/2df51563-cd74-4475-8169-901d3654fda2.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._2df51563-cd74-4475-8169-901d3654fda2.tiff
#   inflating: Cell_ROI_Images/._2df51563-cd74-4475-8169-901d3654fda2.tiff
#   inflating: Cell_ROI_Images/baca0b47-f170-4448-b6c5-ad1865297adf.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._baca0b47-f170-4448-b6c5-ad1865297adf.tiff
#   inflating: Cell_ROI_Images/._baca0b47-f170-4448-b6c5-ad1865297adf.tiff
#   inflating: Cell_ROI_Images/75fdbac9-8846-404e-9bf0-179f71eac750.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._75fdbac9-8846-404e-9bf0-179f71eac750.tiff
#   inflating: Cell_ROI_Images/._75fdbac9-8846-404e-9bf0-179f71eac750.tiff
#   inflating: Cell_ROI_Images/f9d649bc-26fe-465b-a4aa-a8f91320e0e8.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._f9d649bc-26fe-465b-a4aa-a8f91320e0e8.tiff
#   inflating: Cell_ROI_Images/._f9d649bc-26fe-465b-a4aa-a8f91320e0e8.tiff
#   inflating: Cell_ROI_Images/220678da-bb8f-4a61-b6b6-d286edf62838.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._220678da-bb8f-4a61-b6b6-d286edf62838.tiff
#   inflating: Cell_ROI_Images/._220678da-bb8f-4a61-b6b6-d286edf62838.tiff
#   inflating: Cell_ROI_Images/2a99d562-f91d-4a69-a39f-684a525e22c8.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._2a99d562-f91d-4a69-a39f-684a525e22c8.tiff
#   inflating: Cell_ROI_Images/._2a99d562-f91d-4a69-a39f-684a525e22c8.tiff
#   inflating: Cell_ROI_Images/b1b8b4df-dd5e-4a88-bfdb-771bde8d0830.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._b1b8b4df-dd5e-4a88-bfdb-771bde8d0830.tiff
#   inflating: Cell_ROI_Images/._b1b8b4df-dd5e-4a88-bfdb-771bde8d0830.tiff
#   inflating: Cell_ROI_Images/48af9f1a-a3f6-4310-b2c4-3e1dffc44518.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._48af9f1a-a3f6-4310-b2c4-3e1dffc44518.tiff
#   inflating: Cell_ROI_Images/._48af9f1a-a3f6-4310-b2c4-3e1dffc44518.tiff
#   inflating: Cell_ROI_Images/3baf2cf7-788b-462c-b29a-94e4114c9a66.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._3baf2cf7-788b-462c-b29a-94e4114c9a66.tiff
#   inflating: Cell_ROI_Images/._3baf2cf7-788b-462c-b29a-94e4114c9a66.tiff
#   inflating: Cell_ROI_Images/5991169a-43c5-458f-918f-00ace74aa77c.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._5991169a-43c5-458f-918f-00ace74aa77c.tiff
#   inflating: Cell_ROI_Images/._5991169a-43c5-458f-918f-00ace74aa77c.tiff
#   inflating: Cell_ROI_Images/dd2e06d4-08df-4ecd-9547-e68399e457a3.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._dd2e06d4-08df-4ecd-9547-e68399e457a3.tiff
#   inflating: Cell_ROI_Images/._dd2e06d4-08df-4ecd-9547-e68399e457a3.tiff
#   inflating: Cell_ROI_Images/63e2fb75-350f-43ec-a0a0-f2aa7fab736a.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._63e2fb75-350f-43ec-a0a0-f2aa7fab736a.tiff
#   inflating: Cell_ROI_Images/._63e2fb75-350f-43ec-a0a0-f2aa7fab736a.tiff
#   inflating: Cell_ROI_Images/236323f2-3230-4781-b2dd-00f95d34edaa.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._236323f2-3230-4781-b2dd-00f95d34edaa.tiff
#   inflating: Cell_ROI_Images/._236323f2-3230-4781-b2dd-00f95d34edaa.tiff
#   inflating: Cell_ROI_Images/2daa0a63-20ff-4351-b1c2-437aca0686f1.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._2daa0a63-20ff-4351-b1c2-437aca0686f1.tiff
#   inflating: Cell_ROI_Images/._2daa0a63-20ff-4351-b1c2-437aca0686f1.tiff
#   inflating: Cell_ROI_Images/4d2fea83-7fdc-4d9b-8b53-44f12934a114.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._4d2fea83-7fdc-4d9b-8b53-44f12934a114.tiff
#   inflating: Cell_ROI_Images/._4d2fea83-7fdc-4d9b-8b53-44f12934a114.tiff
#   inflating: Cell_ROI_Images/77907eb9-78b9-4f98-8024-2158764090b5.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._77907eb9-78b9-4f98-8024-2158764090b5.tiff
#   inflating: Cell_ROI_Images/._77907eb9-78b9-4f98-8024-2158764090b5.tiff
#   inflating: Cell_ROI_Images/c20d6f4e-a831-451d-87ad-7f53b3a31e41.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._c20d6f4e-a831-451d-87ad-7f53b3a31e41.tiff
#   inflating: Cell_ROI_Images/._c20d6f4e-a831-451d-87ad-7f53b3a31e41.tiff
#   inflating: Cell_ROI_Images/532297fa-f365-450a-88b2-dc959c972fcc.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._532297fa-f365-450a-88b2-dc959c972fcc.tiff
#   inflating: Cell_ROI_Images/._532297fa-f365-450a-88b2-dc959c972fcc.tiff
#   inflating: Cell_ROI_Images/c582e1e8-b07e-4b15-a01a-1c22b384606f.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._c582e1e8-b07e-4b15-a01a-1c22b384606f.tiff
#   inflating: Cell_ROI_Images/._c582e1e8-b07e-4b15-a01a-1c22b384606f.tiff
#   inflating: Cell_ROI_Images/45af8577-30a9-401a-a4f6-c2ac5334094f.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._45af8577-30a9-401a-a4f6-c2ac5334094f.tiff
#   inflating: Cell_ROI_Images/._45af8577-30a9-401a-a4f6-c2ac5334094f.tiff
#   inflating: Cell_ROI_Images/14c3de86-e651-409b-b904-e5279d2646b4.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._14c3de86-e651-409b-b904-e5279d2646b4.tiff
#   inflating: Cell_ROI_Images/._14c3de86-e651-409b-b904-e5279d2646b4.tiff
#   inflating: Cell_ROI_Images/6b21e147-f13a-4716-96c7-9462c9f13529.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._6b21e147-f13a-4716-96c7-9462c9f13529.tiff
#   inflating: Cell_ROI_Images/._6b21e147-f13a-4716-96c7-9462c9f13529.tiff
#   inflating: Cell_ROI_Images/5fafa185-51f6-4319-a3fe-5136fd2fdb68.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._5fafa185-51f6-4319-a3fe-5136fd2fdb68.tiff
#   inflating: Cell_ROI_Images/._5fafa185-51f6-4319-a3fe-5136fd2fdb68.tiff
#   inflating: Cell_ROI_Images/f9c228ff-c8d6-40c0-b8b5-9f152b6a7598.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._f9c228ff-c8d6-40c0-b8b5-9f152b6a7598.tiff
#   inflating: Cell_ROI_Images/._f9c228ff-c8d6-40c0-b8b5-9f152b6a7598.tiff
#   inflating: Cell_ROI_Images/836fc1d8-25b0-4e3e-bd42-0ad0594dcd87.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._836fc1d8-25b0-4e3e-bd42-0ad0594dcd87.tiff
#   inflating: Cell_ROI_Images/._836fc1d8-25b0-4e3e-bd42-0ad0594dcd87.tiff
#   inflating: Cell_ROI_Images/3bb017d9-829f-439f-8e3e-da23730e60d4.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._3bb017d9-829f-439f-8e3e-da23730e60d4.tiff
#   inflating: Cell_ROI_Images/._3bb017d9-829f-439f-8e3e-da23730e60d4.tiff
#   inflating: Cell_ROI_Images/496e27a9-d81d-408c-adb1-74dcc657f119.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._496e27a9-d81d-408c-adb1-74dcc657f119.tiff
#   inflating: Cell_ROI_Images/._496e27a9-d81d-408c-adb1-74dcc657f119.tiff
#   inflating: Cell_ROI_Images/3a4b0012-6e11-4f71-8494-c77df310a7a2.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._3a4b0012-6e11-4f71-8494-c77df310a7a2.tiff
#   inflating: Cell_ROI_Images/._3a4b0012-6e11-4f71-8494-c77df310a7a2.tiff
#   inflating: Cell_ROI_Images/85e41ccb-918b-4255-a57b-e8eb60d28200.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._85e41ccb-918b-4255-a57b-e8eb60d28200.tiff
#   inflating: Cell_ROI_Images/._85e41ccb-918b-4255-a57b-e8eb60d28200.tiff
#   inflating: Cell_ROI_Images/7a03684d-3d17-436d-b46e-05b99becceda.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._7a03684d-3d17-436d-b46e-05b99becceda.tiff
#   inflating: Cell_ROI_Images/._7a03684d-3d17-436d-b46e-05b99becceda.tiff
#   inflating: Cell_ROI_Images/.DS_Store
#   inflating: __MACOSX/Cell_ROI_Images/._.DS_Store
#   inflating: Cell_ROI_Images/._.DS_Store
#   inflating: Cell_ROI_Images/d88e0c79-454e-4a53-b6af-387895574adb.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._d88e0c79-454e-4a53-b6af-387895574adb.tiff
#   inflating: Cell_ROI_Images/._d88e0c79-454e-4a53-b6af-387895574adb.tiff
#   inflating: Cell_ROI_Images/90bcd630-7681-4ff8-986d-2de3257c31d6.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._90bcd630-7681-4ff8-986d-2de3257c31d6.tiff
#   inflating: Cell_ROI_Images/._90bcd630-7681-4ff8-986d-2de3257c31d6.tiff
#   inflating: Cell_ROI_Images/0399de8e-a8aa-4c5a-a9bb-a2f79e347ad2.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._0399de8e-a8aa-4c5a-a9bb-a2f79e347ad2.tiff
#   inflating: Cell_ROI_Images/._0399de8e-a8aa-4c5a-a9bb-a2f79e347ad2.tiff
#   inflating: Cell_ROI_Images/b5a1e1f2-d2b8-4886-82b2-ec5029e2eed9.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._b5a1e1f2-d2b8-4886-82b2-ec5029e2eed9.tiff
#   inflating: Cell_ROI_Images/._b5a1e1f2-d2b8-4886-82b2-ec5029e2eed9.tiff
#   inflating: Cell_ROI_Images/8c5e43bc-449b-4bc5-b8fe-b6ee94e66849.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._8c5e43bc-449b-4bc5-b8fe-b6ee94e66849.tiff
#   inflating: Cell_ROI_Images/._8c5e43bc-449b-4bc5-b8fe-b6ee94e66849.tiff
#   inflating: Cell_ROI_Images/f31685d1-566f-40b4-9128-55405c95727b.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._f31685d1-566f-40b4-9128-55405c95727b.tiff
#   inflating: Cell_ROI_Images/._f31685d1-566f-40b4-9128-55405c95727b.tiff
#   inflating: Cell_ROI_Images/0db19a17-8ad3-47a9-8ce6-5f2415b4d87d.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._0db19a17-8ad3-47a9-8ce6-5f2415b4d87d.tiff
#   inflating: Cell_ROI_Images/._0db19a17-8ad3-47a9-8ce6-5f2415b4d87d.tiff
#   inflating: Cell_ROI_Images/79c07c92-b8fe-4c28-9d60-29aa3b4e7444.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._79c07c92-b8fe-4c28-9d60-29aa3b4e7444.tiff
#   inflating: Cell_ROI_Images/._79c07c92-b8fe-4c28-9d60-29aa3b4e7444.tiff
#   inflating: Cell_ROI_Images/a92e4f16-684e-427a-b0d4-bc6931353280.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._a92e4f16-684e-427a-b0d4-bc6931353280.tiff
#   inflating: Cell_ROI_Images/._a92e4f16-684e-427a-b0d4-bc6931353280.tiff
#   inflating: Cell_ROI_Images/7fa7f347-87e2-4282-8aa3-e0e3201c1eb6.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._7fa7f347-87e2-4282-8aa3-e0e3201c1eb6.tiff
#   inflating: Cell_ROI_Images/._7fa7f347-87e2-4282-8aa3-e0e3201c1eb6.tiff
#   inflating: Cell_ROI_Images/bda958c9-01a8-4532-b1a2-7268745f77d4.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._bda958c9-01a8-4532-b1a2-7268745f77d4.tiff
#   inflating: Cell_ROI_Images/._bda958c9-01a8-4532-b1a2-7268745f77d4.tiff
#   inflating: Cell_ROI_Images/ad673993-47ed-4eed-a539-d982c3d2996b.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._ad673993-47ed-4eed-a539-d982c3d2996b.tiff
#   inflating: Cell_ROI_Images/._ad673993-47ed-4eed-a539-d982c3d2996b.tiff
#   inflating: Cell_ROI_Images/fa869ff3-83e0-4d20-be4d-8af8edba06bc.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._fa869ff3-83e0-4d20-be4d-8af8edba06bc.tiff
#   inflating: Cell_ROI_Images/._fa869ff3-83e0-4d20-be4d-8af8edba06bc.tiff
#   inflating: Cell_ROI_Images/d9827f0b-6ccd-48d9-a8fe-a523cd2464a4.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._d9827f0b-6ccd-48d9-a8fe-a523cd2464a4.tiff
#   inflating: Cell_ROI_Images/._d9827f0b-6ccd-48d9-a8fe-a523cd2464a4.tiff
#   inflating: Cell_ROI_Images/a06531b5-bbc2-4aa8-b3e7-516c7fbd563f.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._a06531b5-bbc2-4aa8-b3e7-516c7fbd563f.tiff
#   inflating: Cell_ROI_Images/._a06531b5-bbc2-4aa8-b3e7-516c7fbd563f.tiff
#   inflating: Cell_ROI_Images/dbb16678-a8ae-4324-8178-8d9e5fdbc3e4.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._dbb16678-a8ae-4324-8178-8d9e5fdbc3e4.tiff
#   inflating: Cell_ROI_Images/._dbb16678-a8ae-4324-8178-8d9e5fdbc3e4.tiff
#   inflating: Cell_ROI_Images/406012c3-0691-44f4-8826-99bfb8adb2cf.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._406012c3-0691-44f4-8826-99bfb8adb2cf.tiff
#   inflating: Cell_ROI_Images/._406012c3-0691-44f4-8826-99bfb8adb2cf.tiff
#   inflating: Cell_ROI_Images/42ebba18-496e-4616-a15c-f5e04e5a63e0.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._42ebba18-496e-4616-a15c-f5e04e5a63e0.tiff
#   inflating: Cell_ROI_Images/._42ebba18-496e-4616-a15c-f5e04e5a63e0.tiff
#   inflating: Cell_ROI_Images/1964e427-0beb-4f08-89b2-13cb6d1558e0.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._1964e427-0beb-4f08-89b2-13cb6d1558e0.tiff
#   inflating: Cell_ROI_Images/._1964e427-0beb-4f08-89b2-13cb6d1558e0.tiff
#   inflating: Cell_ROI_Images/8981b702-2c1a-4bdd-bf48-d2306d52f2af.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._8981b702-2c1a-4bdd-bf48-d2306d52f2af.tiff
#   inflating: Cell_ROI_Images/._8981b702-2c1a-4bdd-bf48-d2306d52f2af.tiff
#   inflating: Cell_ROI_Images/c5cebbb6-6ec6-4501-a763-078d121fdd60.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._c5cebbb6-6ec6-4501-a763-078d121fdd60.tiff
#   inflating: Cell_ROI_Images/._c5cebbb6-6ec6-4501-a763-078d121fdd60.tiff
#   inflating: Cell_ROI_Images/81b67bc7-f529-4fac-b3f1-57d68fe863f3.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._81b67bc7-f529-4fac-b3f1-57d68fe863f3.tiff
#   inflating: Cell_ROI_Images/._81b67bc7-f529-4fac-b3f1-57d68fe863f3.tiff
#   inflating: Cell_ROI_Images/3917050d-280a-4e19-9fbc-a345918c6c5c.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._3917050d-280a-4e19-9fbc-a345918c6c5c.tiff
#   inflating: Cell_ROI_Images/._3917050d-280a-4e19-9fbc-a345918c6c5c.tiff
#   inflating: Cell_ROI_Images/60dec555-ab67-4fbe-a010-7114ad12ab07.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._60dec555-ab67-4fbe-a010-7114ad12ab07.tiff
#   inflating: Cell_ROI_Images/._60dec555-ab67-4fbe-a010-7114ad12ab07.tiff
#   inflating: Cell_ROI_Images/0f3aab68-41c4-4fe0-9564-d8d82a2acfa1.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._0f3aab68-41c4-4fe0-9564-d8d82a2acfa1.tiff
#   inflating: Cell_ROI_Images/._0f3aab68-41c4-4fe0-9564-d8d82a2acfa1.tiff
#   inflating: Cell_ROI_Images/777f9433-b024-4121-89af-f2d7877d15c8.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._777f9433-b024-4121-89af-f2d7877d15c8.tiff
#   inflating: Cell_ROI_Images/._777f9433-b024-4121-89af-f2d7877d15c8.tiff
#   inflating: Cell_ROI_Images/187eb8dd-5eb8-4134-ac03-83bf57c5ca93.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._187eb8dd-5eb8-4134-ac03-83bf57c5ca93.tiff
#   inflating: Cell_ROI_Images/._187eb8dd-5eb8-4134-ac03-83bf57c5ca93.tiff
#   inflating: Cell_ROI_Images/1644b46f-afee-4957-ae76-a96aa46d6c45.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._1644b46f-afee-4957-ae76-a96aa46d6c45.tiff
#   inflating: Cell_ROI_Images/._1644b46f-afee-4957-ae76-a96aa46d6c45.tiff
#   inflating: Cell_ROI_Images/70b4a59c-e8e4-464f-b64b-8687870a42cc.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._70b4a59c-e8e4-464f-b64b-8687870a42cc.tiff
#   inflating: Cell_ROI_Images/._70b4a59c-e8e4-464f-b64b-8687870a42cc.tiff
#   inflating: Cell_ROI_Images/c4ae04ca-844e-4957-bd71-4bacd924a662.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._c4ae04ca-844e-4957-bd71-4bacd924a662.tiff
#   inflating: Cell_ROI_Images/._c4ae04ca-844e-4957-bd71-4bacd924a662.tiff
#   inflating: Cell_ROI_Images/d927a8e3-0645-4c4c-90ba-34b264e3549e.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._d927a8e3-0645-4c4c-90ba-34b264e3549e.tiff
#   inflating: Cell_ROI_Images/._d927a8e3-0645-4c4c-90ba-34b264e3549e.tiff
#   inflating: Cell_ROI_Images/37a48128-7240-4718-a268-9c4e35178681.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._37a48128-7240-4718-a268-9c4e35178681.tiff
#   inflating: Cell_ROI_Images/._37a48128-7240-4718-a268-9c4e35178681.tiff
#   inflating: Cell_ROI_Images/5787266d-2b9e-49c0-9be5-c135caafdf18.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._5787266d-2b9e-49c0-9be5-c135caafdf18.tiff
#   inflating: Cell_ROI_Images/._5787266d-2b9e-49c0-9be5-c135caafdf18.tiff
#   inflating: Cell_ROI_Images/01fc79cc-72d7-4d1d-912f-30f0a162852b.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._01fc79cc-72d7-4d1d-912f-30f0a162852b.tiff
#   inflating: Cell_ROI_Images/._01fc79cc-72d7-4d1d-912f-30f0a162852b.tiff
#   inflating: Cell_ROI_Images/afa3d6ba-37b8-41db-bddd-038c21d9f61e.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._afa3d6ba-37b8-41db-bddd-038c21d9f61e.tiff
#   inflating: Cell_ROI_Images/._afa3d6ba-37b8-41db-bddd-038c21d9f61e.tiff
#   inflating: Cell_ROI_Images/cff0a6c0-0a63-4583-b6b2-1dcdb50871e1.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._cff0a6c0-0a63-4583-b6b2-1dcdb50871e1.tiff
#   inflating: Cell_ROI_Images/._cff0a6c0-0a63-4583-b6b2-1dcdb50871e1.tiff
#   inflating: Cell_ROI_Images/a726ce01-610b-4568-b0d2-9e18514efe7d.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._a726ce01-610b-4568-b0d2-9e18514efe7d.tiff
#   inflating: Cell_ROI_Images/._a726ce01-610b-4568-b0d2-9e18514efe7d.tiff
#   inflating: Cell_ROI_Images/6c6362ca-8a04-4a1c-8fd8-8ec541ef99d0.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._6c6362ca-8a04-4a1c-8fd8-8ec541ef99d0.tiff
#   inflating: Cell_ROI_Images/._6c6362ca-8a04-4a1c-8fd8-8ec541ef99d0.tiff
#   inflating: Cell_ROI_Images/de72c8be-eaf4-43fe-8baf-04a20d1cc83c.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._de72c8be-eaf4-43fe-8baf-04a20d1cc83c.tiff
#   inflating: Cell_ROI_Images/._de72c8be-eaf4-43fe-8baf-04a20d1cc83c.tiff
#   inflating: Cell_ROI_Images/def2c104-8cc7-4036-b4ce-ca1fb5a7d098.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._def2c104-8cc7-4036-b4ce-ca1fb5a7d098.tiff
#   inflating: Cell_ROI_Images/._def2c104-8cc7-4036-b4ce-ca1fb5a7d098.tiff
#   inflating: Cell_ROI_Images/0a4f9e9e-9898-4c3c-b538-6ddbf7b6deae.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._0a4f9e9e-9898-4c3c-b538-6ddbf7b6deae.tiff
#   inflating: Cell_ROI_Images/._0a4f9e9e-9898-4c3c-b538-6ddbf7b6deae.tiff
#   inflating: Cell_ROI_Images/c8298e96-2103-4f8c-8226-2976f1c627c5.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._c8298e96-2103-4f8c-8226-2976f1c627c5.tiff
#   inflating: Cell_ROI_Images/._c8298e96-2103-4f8c-8226-2976f1c627c5.tiff
#   inflating: Cell_ROI_Images/23549475-b48e-4f45-ad6a-103be2094e20.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._23549475-b48e-4f45-ad6a-103be2094e20.tiff
#   inflating: Cell_ROI_Images/._23549475-b48e-4f45-ad6a-103be2094e20.tiff
#   inflating: Cell_ROI_Images/4c5a5c97-87b1-4dde-abf2-c079c20c3fb4.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._4c5a5c97-87b1-4dde-abf2-c079c20c3fb4.tiff
#   inflating: Cell_ROI_Images/._4c5a5c97-87b1-4dde-abf2-c079c20c3fb4.tiff
#   inflating: Cell_ROI_Images/9df4f44b-a722-4714-8cae-4f477cdc2437.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._9df4f44b-a722-4714-8cae-4f477cdc2437.tiff
#   inflating: Cell_ROI_Images/._9df4f44b-a722-4714-8cae-4f477cdc2437.tiff
#   inflating: Cell_ROI_Images/7fc820ee-7400-49da-813c-c03a3bb5a087.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._7fc820ee-7400-49da-813c-c03a3bb5a087.tiff
#   inflating: Cell_ROI_Images/._7fc820ee-7400-49da-813c-c03a3bb5a087.tiff
#   inflating: Cell_ROI_Images/b103218a-7849-468a-a0f5-07344733acf0.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._b103218a-7849-468a-a0f5-07344733acf0.tiff
#   inflating: Cell_ROI_Images/._b103218a-7849-468a-a0f5-07344733acf0.tiff
#   inflating: Cell_ROI_Images/98bec899-e1bd-43ff-b983-cc7b75332f99.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._98bec899-e1bd-43ff-b983-cc7b75332f99.tiff
#   inflating: Cell_ROI_Images/._98bec899-e1bd-43ff-b983-cc7b75332f99.tiff
#   inflating: Cell_ROI_Images/724d8e27-3f97-4324-befc-ef7d5b23e000.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._724d8e27-3f97-4324-befc-ef7d5b23e000.tiff
#   inflating: Cell_ROI_Images/._724d8e27-3f97-4324-befc-ef7d5b23e000.tiff
#   inflating: Cell_ROI_Images/8fb4b227-e4ee-4cc0-856a-1e89f562a097.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._8fb4b227-e4ee-4cc0-856a-1e89f562a097.tiff
#   inflating: Cell_ROI_Images/._8fb4b227-e4ee-4cc0-856a-1e89f562a097.tiff
#   inflating: Cell_ROI_Images/b496942d-2eee-4d1d-8e4e-376fcb352bdd.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._b496942d-2eee-4d1d-8e4e-376fcb352bdd.tiff
#   inflating: Cell_ROI_Images/._b496942d-2eee-4d1d-8e4e-376fcb352bdd.tiff
#   inflating: Cell_ROI_Images/835a384d-b903-42bb-8af3-c4abd5907ccf.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._835a384d-b903-42bb-8af3-c4abd5907ccf.tiff
#   inflating: Cell_ROI_Images/._835a384d-b903-42bb-8af3-c4abd5907ccf.tiff
#   inflating: Cell_ROI_Images/dca05b76-6c6b-477b-b32c-38f52fa07976.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._dca05b76-6c6b-477b-b32c-38f52fa07976.tiff
#   inflating: Cell_ROI_Images/._dca05b76-6c6b-477b-b32c-38f52fa07976.tiff
#   inflating: Cell_ROI_Images/bbb30233-94a1-44b5-b8a7-b55c366687f0.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._bbb30233-94a1-44b5-b8a7-b55c366687f0.tiff
#   inflating: Cell_ROI_Images/._bbb30233-94a1-44b5-b8a7-b55c366687f0.tiff
#   inflating: Cell_ROI_Images/39ec114a-84fe-4fd9-8b47-4601eda107b2.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._39ec114a-84fe-4fd9-8b47-4601eda107b2.tiff
#   inflating: Cell_ROI_Images/._39ec114a-84fe-4fd9-8b47-4601eda107b2.tiff
#   inflating: Cell_ROI_Images/d3f07304-530b-4bcf-bf44-c4412532e9da.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._d3f07304-530b-4bcf-bf44-c4412532e9da.tiff
#   inflating: Cell_ROI_Images/._d3f07304-530b-4bcf-bf44-c4412532e9da.tiff
#   inflating: Cell_ROI_Images/f5b5f5e1-1906-4f5d-bb4f-a1f2e7647966.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._f5b5f5e1-1906-4f5d-bb4f-a1f2e7647966.tiff
#   inflating: Cell_ROI_Images/._f5b5f5e1-1906-4f5d-bb4f-a1f2e7647966.tiff
#   inflating: Cell_ROI_Images/4791d2a6-d2a9-49e5-aa8f-2d4c012da36f.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._4791d2a6-d2a9-49e5-aa8f-2d4c012da36f.tiff
#   inflating: Cell_ROI_Images/._4791d2a6-d2a9-49e5-aa8f-2d4c012da36f.tiff
#   inflating: Cell_ROI_Images/eb35c020-a660-4ca0-8c9b-b54a8e11798e.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._eb35c020-a660-4ca0-8c9b-b54a8e11798e.tiff
#   inflating: Cell_ROI_Images/._eb35c020-a660-4ca0-8c9b-b54a8e11798e.tiff
#   inflating: Cell_ROI_Images/9f07bd1f-f848-43d9-b970-8ce7c0940d07.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._9f07bd1f-f848-43d9-b970-8ce7c0940d07.tiff
#   inflating: Cell_ROI_Images/._9f07bd1f-f848-43d9-b970-8ce7c0940d07.tiff
#   inflating: Cell_ROI_Images/70872f6f-daa3-4b84-9f35-3a2c337179d7.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._70872f6f-daa3-4b84-9f35-3a2c337179d7.tiff
#   inflating: Cell_ROI_Images/._70872f6f-daa3-4b84-9f35-3a2c337179d7.tiff
#   inflating: Cell_ROI_Images/806f68aa-434e-4538-b712-3557c20f4886.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._806f68aa-434e-4538-b712-3557c20f4886.tiff
#   inflating: Cell_ROI_Images/._806f68aa-434e-4538-b712-3557c20f4886.tiff
#   inflating: Cell_ROI_Images/7ba76bcc-4bfb-4216-a2b4-e7afac874dda.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._7ba76bcc-4bfb-4216-a2b4-e7afac874dda.tiff
#   inflating: Cell_ROI_Images/._7ba76bcc-4bfb-4216-a2b4-e7afac874dda.tiff
#   inflating: Cell_ROI_Images/0ce8a79f-9bb1-4dc7-992f-fe79a5bba620.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._0ce8a79f-9bb1-4dc7-992f-fe79a5bba620.tiff
#   inflating: Cell_ROI_Images/._0ce8a79f-9bb1-4dc7-992f-fe79a5bba620.tiff
#   inflating: Cell_ROI_Images/30f544d1-1f92-4f10-872b-c15420b563a4.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._30f544d1-1f92-4f10-872b-c15420b563a4.tiff
#   inflating: Cell_ROI_Images/._30f544d1-1f92-4f10-872b-c15420b563a4.tiff
#   inflating: Cell_ROI_Images/394925dd-67de-4366-b211-f1194f42b4b9.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._394925dd-67de-4366-b211-f1194f42b4b9.tiff
#   inflating: Cell_ROI_Images/._394925dd-67de-4366-b211-f1194f42b4b9.tiff
#   inflating: Cell_ROI_Images/40b9fb4f-438f-47bb-929a-b3022e037cd4.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._40b9fb4f-438f-47bb-929a-b3022e037cd4.tiff
#   inflating: Cell_ROI_Images/._40b9fb4f-438f-47bb-929a-b3022e037cd4.tiff
#   inflating: Cell_ROI_Images/928f8272-00c9-42cb-9bcd-d418ccab39cf.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._928f8272-00c9-42cb-9bcd-d418ccab39cf.tiff
#   inflating: Cell_ROI_Images/._928f8272-00c9-42cb-9bcd-d418ccab39cf.tiff
#   inflating: Cell_ROI_Images/701a749d-147a-4f28-b1db-826b0432bad5.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._701a749d-147a-4f28-b1db-826b0432bad5.tiff
#   inflating: Cell_ROI_Images/._701a749d-147a-4f28-b1db-826b0432bad5.tiff
#   inflating: Cell_ROI_Images/5299a7c6-774f-4907-badb-6445867a00e0.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._5299a7c6-774f-4907-badb-6445867a00e0.tiff
#   inflating: Cell_ROI_Images/._5299a7c6-774f-4907-badb-6445867a00e0.tiff
#   inflating: Cell_ROI_Images/be542e75-0801-4212-9880-91c3b8d2f892.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._be542e75-0801-4212-9880-91c3b8d2f892.tiff
#   inflating: Cell_ROI_Images/._be542e75-0801-4212-9880-91c3b8d2f892.tiff
#   inflating: Cell_ROI_Images/8a255358-c48e-49d5-a34c-82a3190e6336.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._8a255358-c48e-49d5-a34c-82a3190e6336.tiff
#   inflating: Cell_ROI_Images/._8a255358-c48e-49d5-a34c-82a3190e6336.tiff
#   inflating: Cell_ROI_Images/9f5b627c-273e-4f78-87a9-1e784702a792.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._9f5b627c-273e-4f78-87a9-1e784702a792.tiff
#   inflating: Cell_ROI_Images/._9f5b627c-273e-4f78-87a9-1e784702a792.tiff
#   inflating: Cell_ROI_Images/6191195b-9dea-4dff-a60e-f84904626c03.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._6191195b-9dea-4dff-a60e-f84904626c03.tiff
#   inflating: Cell_ROI_Images/._6191195b-9dea-4dff-a60e-f84904626c03.tiff
#   inflating: Cell_ROI_Images/4cb0c4c2-62c4-4843-90cb-f9b96285dbc3.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._4cb0c4c2-62c4-4843-90cb-f9b96285dbc3.tiff
#   inflating: Cell_ROI_Images/._4cb0c4c2-62c4-4843-90cb-f9b96285dbc3.tiff
#   inflating: Cell_ROI_Images/24c16922-2876-431b-8876-647373f7bbbd.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._24c16922-2876-431b-8876-647373f7bbbd.tiff
#   inflating: Cell_ROI_Images/._24c16922-2876-431b-8876-647373f7bbbd.tiff
#   inflating: Cell_ROI_Images/84d32539-54c6-4a79-ac0a-559aace2ca25.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._84d32539-54c6-4a79-ac0a-559aace2ca25.tiff
#   inflating: Cell_ROI_Images/._84d32539-54c6-4a79-ac0a-559aace2ca25.tiff
#   inflating: Cell_ROI_Images/fe7e9b7a-cc3f-4def-a5f1-f47565764731.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._fe7e9b7a-cc3f-4def-a5f1-f47565764731.tiff
#   inflating: Cell_ROI_Images/._fe7e9b7a-cc3f-4def-a5f1-f47565764731.tiff
#   inflating: Cell_ROI_Images/56e66b3f-2a43-409a-bc9d-808b6e88cbc1.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._56e66b3f-2a43-409a-bc9d-808b6e88cbc1.tiff
#   inflating: Cell_ROI_Images/._56e66b3f-2a43-409a-bc9d-808b6e88cbc1.tiff
#   inflating: Cell_ROI_Images/adc21892-6e79-4873-90da-19a1dcad9e14.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._adc21892-6e79-4873-90da-19a1dcad9e14.tiff
#   inflating: Cell_ROI_Images/._adc21892-6e79-4873-90da-19a1dcad9e14.tiff
#   inflating: Cell_ROI_Images/7eb547b7-c618-4c56-a35b-9fecaca8bdf0.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._7eb547b7-c618-4c56-a35b-9fecaca8bdf0.tiff
#   inflating: Cell_ROI_Images/._7eb547b7-c618-4c56-a35b-9fecaca8bdf0.tiff
#   inflating: Cell_ROI_Images/a31c0845-6c4b-48f5-aa03-4202ff4108dd.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._a31c0845-6c4b-48f5-aa03-4202ff4108dd.tiff
#   inflating: Cell_ROI_Images/._a31c0845-6c4b-48f5-aa03-4202ff4108dd.tiff
#   inflating: Cell_ROI_Images/7d57cf1d-7f29-4fbb-8caa-fae4c51a2f19.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._7d57cf1d-7f29-4fbb-8caa-fae4c51a2f19.tiff
#   inflating: Cell_ROI_Images/._7d57cf1d-7f29-4fbb-8caa-fae4c51a2f19.tiff
#   inflating: Cell_ROI_Images/e63abcc4-0912-4445-ba64-2884ac100e23.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._e63abcc4-0912-4445-ba64-2884ac100e23.tiff
#   inflating: Cell_ROI_Images/._e63abcc4-0912-4445-ba64-2884ac100e23.tiff
#   inflating: Cell_ROI_Images/3868798a-f4d4-4eb2-ab3a-2d66349a492e.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._3868798a-f4d4-4eb2-ab3a-2d66349a492e.tiff
#   inflating: Cell_ROI_Images/._3868798a-f4d4-4eb2-ab3a-2d66349a492e.tiff
#   inflating: Cell_ROI_Images/493e4241-6416-4604-8aa1-1dfb3251caa3.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._493e4241-6416-4604-8aa1-1dfb3251caa3.tiff
#   inflating: Cell_ROI_Images/._493e4241-6416-4604-8aa1-1dfb3251caa3.tiff
#   inflating: Cell_ROI_Images/91d5bec2-0abb-4ad5-ac10-f0c20156b819.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._91d5bec2-0abb-4ad5-ac10-f0c20156b819.tiff
#   inflating: Cell_ROI_Images/._91d5bec2-0abb-4ad5-ac10-f0c20156b819.tiff
#   inflating: Cell_ROI_Images/6b54c3f2-90e7-493e-b68a-a3aed60e6c34.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._6b54c3f2-90e7-493e-b68a-a3aed60e6c34.tiff
#   inflating: Cell_ROI_Images/._6b54c3f2-90e7-493e-b68a-a3aed60e6c34.tiff
#   inflating: Cell_ROI_Images/233e009d-197a-4d15-9f21-ca54314475f8.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._233e009d-197a-4d15-9f21-ca54314475f8.tiff
#   inflating: Cell_ROI_Images/._233e009d-197a-4d15-9f21-ca54314475f8.tiff
#   inflating: Cell_ROI_Images/a3246ad6-0f10-4579-8209-a477c5e965c5.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._a3246ad6-0f10-4579-8209-a477c5e965c5.tiff
#   inflating: Cell_ROI_Images/._a3246ad6-0f10-4579-8209-a477c5e965c5.tiff
#   inflating: Cell_ROI_Images/822502b1-3f15-44e9-86fd-2133e39ad1c1.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._822502b1-3f15-44e9-86fd-2133e39ad1c1.tiff
#   inflating: Cell_ROI_Images/._822502b1-3f15-44e9-86fd-2133e39ad1c1.tiff
#   inflating: Cell_ROI_Images/edaa0206-da26-444b-bf46-fb52c042b3d4.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._edaa0206-da26-444b-bf46-fb52c042b3d4.tiff
#   inflating: Cell_ROI_Images/._edaa0206-da26-444b-bf46-fb52c042b3d4.tiff
#   inflating: Cell_ROI_Images/1d9abb2a-7aad-4423-a1d5-eccf6f8b21b2.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._1d9abb2a-7aad-4423-a1d5-eccf6f8b21b2.tiff
#   inflating: Cell_ROI_Images/._1d9abb2a-7aad-4423-a1d5-eccf6f8b21b2.tiff
#   inflating: Cell_ROI_Images/71d10bfd-f13a-471a-b244-c2b2bf8267af.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._71d10bfd-f13a-471a-b244-c2b2bf8267af.tiff
#   inflating: Cell_ROI_Images/._71d10bfd-f13a-471a-b244-c2b2bf8267af.tiff
#   inflating: Cell_ROI_Images/07630b8d-4981-43df-a63c-3f8a0f54652f.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._07630b8d-4981-43df-a63c-3f8a0f54652f.tiff
#   inflating: Cell_ROI_Images/._07630b8d-4981-43df-a63c-3f8a0f54652f.tiff
#   inflating: Cell_ROI_Images/261e7a4f-44b2-4a6e-8c07-48973eb850dc.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._261e7a4f-44b2-4a6e-8c07-48973eb850dc.tiff
#   inflating: Cell_ROI_Images/._261e7a4f-44b2-4a6e-8c07-48973eb850dc.tiff
#   inflating: Cell_ROI_Images/7df181de-6a3f-489e-b0cd-22af68fea39a.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._7df181de-6a3f-489e-b0cd-22af68fea39a.tiff
#   inflating: Cell_ROI_Images/._7df181de-6a3f-489e-b0cd-22af68fea39a.tiff
#   inflating: Cell_ROI_Images/64b01a0d-3275-43fd-bff5-be64e7a1c755.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._64b01a0d-3275-43fd-bff5-be64e7a1c755.tiff
#   inflating: Cell_ROI_Images/._64b01a0d-3275-43fd-bff5-be64e7a1c755.tiff
#   inflating: Cell_ROI_Images/003aebba-e366-4505-85dc-c16c20fd4d9b.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._003aebba-e366-4505-85dc-c16c20fd4d9b.tiff
#   inflating: Cell_ROI_Images/._003aebba-e366-4505-85dc-c16c20fd4d9b.tiff
#   inflating: Cell_ROI_Images/d07349e0-236e-4a3b-8121-504133ba380d.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._d07349e0-236e-4a3b-8121-504133ba380d.tiff
#   inflating: Cell_ROI_Images/._d07349e0-236e-4a3b-8121-504133ba380d.tiff
#   inflating: Cell_ROI_Images/1f14e22d-2764-4110-aa13-d59bb8418c0b.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._1f14e22d-2764-4110-aa13-d59bb8418c0b.tiff
#   inflating: Cell_ROI_Images/._1f14e22d-2764-4110-aa13-d59bb8418c0b.tiff
#   inflating: Cell_ROI_Images/d2da8428-614b-4e6f-982a-8af0048ea1ce.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._d2da8428-614b-4e6f-982a-8af0048ea1ce.tiff
#   inflating: Cell_ROI_Images/._d2da8428-614b-4e6f-982a-8af0048ea1ce.tiff
#   inflating: Cell_ROI_Images/608d4de6-d415-495c-922b-3df49dd68b93.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._608d4de6-d415-495c-922b-3df49dd68b93.tiff
#   inflating: Cell_ROI_Images/._608d4de6-d415-495c-922b-3df49dd68b93.tiff
#   inflating: Cell_ROI_Images/e4ea151e-dc5f-4d8d-872e-85faecf14f6f.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._e4ea151e-dc5f-4d8d-872e-85faecf14f6f.tiff
#   inflating: Cell_ROI_Images/._e4ea151e-dc5f-4d8d-872e-85faecf14f6f.tiff
#   inflating: Cell_ROI_Images/b2116a3e-5226-493a-935c-89888ee9d4e3.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._b2116a3e-5226-493a-935c-89888ee9d4e3.tiff
#   inflating: Cell_ROI_Images/._b2116a3e-5226-493a-935c-89888ee9d4e3.tiff
#   inflating: Cell_ROI_Images/9af73930-05bb-4302-878f-165758ce2463.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._9af73930-05bb-4302-878f-165758ce2463.tiff
#   inflating: Cell_ROI_Images/._9af73930-05bb-4302-878f-165758ce2463.tiff
#   inflating: Cell_ROI_Images/eafd0dde-4849-4407-9736-690634af3039.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._eafd0dde-4849-4407-9736-690634af3039.tiff
#   inflating: Cell_ROI_Images/._eafd0dde-4849-4407-9736-690634af3039.tiff
#   inflating: Cell_ROI_Images/83d991b5-fdf6-4053-8100-2ceb66dbcac1.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._83d991b5-fdf6-4053-8100-2ceb66dbcac1.tiff
#   inflating: Cell_ROI_Images/._83d991b5-fdf6-4053-8100-2ceb66dbcac1.tiff
#   inflating: Cell_ROI_Images/9c802aad-ddf7-4aed-9947-af1d8ff38002.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._9c802aad-ddf7-4aed-9947-af1d8ff38002.tiff
#   inflating: Cell_ROI_Images/._9c802aad-ddf7-4aed-9947-af1d8ff38002.tiff
#   inflating: Cell_ROI_Images/1001ab99-6a6e-411f-9580-da449593a44c.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._1001ab99-6a6e-411f-9580-da449593a44c.tiff
#   inflating: Cell_ROI_Images/._1001ab99-6a6e-411f-9580-da449593a44c.tiff
#   inflating: Cell_ROI_Images/964e9e42-9c48-4127-ae9c-6f928e4ae0d5.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._964e9e42-9c48-4127-ae9c-6f928e4ae0d5.tiff
#   inflating: Cell_ROI_Images/._964e9e42-9c48-4127-ae9c-6f928e4ae0d5.tiff
#   inflating: Cell_ROI_Images/1ef51ef2-9a94-455a-883c-d3280bdd9094.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._1ef51ef2-9a94-455a-883c-d3280bdd9094.tiff
#   inflating: Cell_ROI_Images/._1ef51ef2-9a94-455a-883c-d3280bdd9094.tiff
#   inflating: Cell_ROI_Images/919adfbb-c5fe-4ac0-9677-5ca22edba09e.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._919adfbb-c5fe-4ac0-9677-5ca22edba09e.tiff
#   inflating: Cell_ROI_Images/._919adfbb-c5fe-4ac0-9677-5ca22edba09e.tiff
#   inflating: Cell_ROI_Images/e9d231b1-2a25-4fb9-853b-c385a95b8894.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._e9d231b1-2a25-4fb9-853b-c385a95b8894.tiff
#   inflating: Cell_ROI_Images/._e9d231b1-2a25-4fb9-853b-c385a95b8894.tiff
#   inflating: Cell_ROI_Images/4397a29a-b778-4567-b72d-3cbbaa4d2a95.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._4397a29a-b778-4567-b72d-3cbbaa4d2a95.tiff
#   inflating: Cell_ROI_Images/._4397a29a-b778-4567-b72d-3cbbaa4d2a95.tiff
#   inflating: Cell_ROI_Images/7a65fdfb-fbb3-4c28-a922-27e4e6589d2e.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._7a65fdfb-fbb3-4c28-a922-27e4e6589d2e.tiff
#   inflating: Cell_ROI_Images/._7a65fdfb-fbb3-4c28-a922-27e4e6589d2e.tiff
#   inflating: Cell_ROI_Images/13d2acc1-57c1-464b-a3f6-b36e7be12ef1.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._13d2acc1-57c1-464b-a3f6-b36e7be12ef1.tiff
#   inflating: Cell_ROI_Images/._13d2acc1-57c1-464b-a3f6-b36e7be12ef1.tiff
#   inflating: Cell_ROI_Images/ac07548a-8f36-42c9-a429-d4f9706e4628.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._ac07548a-8f36-42c9-a429-d4f9706e4628.tiff
#   inflating: Cell_ROI_Images/._ac07548a-8f36-42c9-a429-d4f9706e4628.tiff
#   inflating: Cell_ROI_Images/46fbd76c-0b5d-45ab-b154-e0ba495a438b.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._46fbd76c-0b5d-45ab-b154-e0ba495a438b.tiff
#   inflating: Cell_ROI_Images/._46fbd76c-0b5d-45ab-b154-e0ba495a438b.tiff
#   inflating: Cell_ROI_Images/63f353ce-034b-48ac-af3a-4e7d2c979058.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._63f353ce-034b-48ac-af3a-4e7d2c979058.tiff
#   inflating: Cell_ROI_Images/._63f353ce-034b-48ac-af3a-4e7d2c979058.tiff
#   inflating: Cell_ROI_Images/b9bb758d-b14a-43c0-bb58-42e202fb992e.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._b9bb758d-b14a-43c0-bb58-42e202fb992e.tiff
#   inflating: Cell_ROI_Images/._b9bb758d-b14a-43c0-bb58-42e202fb992e.tiff
#   inflating: Cell_ROI_Images/fbb9c53b-5451-4dcb-9830-b1cb5d0dcd92.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._fbb9c53b-5451-4dcb-9830-b1cb5d0dcd92.tiff
#   inflating: Cell_ROI_Images/._fbb9c53b-5451-4dcb-9830-b1cb5d0dcd92.tiff
#   inflating: Cell_ROI_Images/09ea02f4-b8ca-48d2-b881-837be9fd3019.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._09ea02f4-b8ca-48d2-b881-837be9fd3019.tiff
#   inflating: Cell_ROI_Images/._09ea02f4-b8ca-48d2-b881-837be9fd3019.tiff
#   inflating: Cell_ROI_Images/68f17ad9-05e1-4a92-89dd-53aae636140b.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._68f17ad9-05e1-4a92-89dd-53aae636140b.tiff
#   inflating: Cell_ROI_Images/._68f17ad9-05e1-4a92-89dd-53aae636140b.tiff
#   inflating: Cell_ROI_Images/4e41cfcc-3bcc-4f7c-b73b-31fe339e736b.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._4e41cfcc-3bcc-4f7c-b73b-31fe339e736b.tiff
#   inflating: Cell_ROI_Images/._4e41cfcc-3bcc-4f7c-b73b-31fe339e736b.tiff
#   inflating: Cell_ROI_Images/d1c0e61b-3a03-4d98-8c71-73f8fed64642.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._d1c0e61b-3a03-4d98-8c71-73f8fed64642.tiff
#   inflating: Cell_ROI_Images/._d1c0e61b-3a03-4d98-8c71-73f8fed64642.tiff
#   inflating: Cell_ROI_Images/ed0143bc-7446-422e-a61c-2fa0484adee0.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._ed0143bc-7446-422e-a61c-2fa0484adee0.tiff
#   inflating: Cell_ROI_Images/._ed0143bc-7446-422e-a61c-2fa0484adee0.tiff
#   inflating: Cell_ROI_Images/881a1ebf-342e-4f6b-bb8e-f80e9d23e4dc.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._881a1ebf-342e-4f6b-bb8e-f80e9d23e4dc.tiff
#   inflating: Cell_ROI_Images/._881a1ebf-342e-4f6b-bb8e-f80e9d23e4dc.tiff
#   inflating: Cell_ROI_Images/6ebcb520-a6ef-429e-ae3f-c07947e4f6fb.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._6ebcb520-a6ef-429e-ae3f-c07947e4f6fb.tiff
#   inflating: Cell_ROI_Images/._6ebcb520-a6ef-429e-ae3f-c07947e4f6fb.tiff
#   inflating: Cell_ROI_Images/12a31225-5038-44f7-9298-cc107d9b361c.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._12a31225-5038-44f7-9298-cc107d9b361c.tiff
#   inflating: Cell_ROI_Images/._12a31225-5038-44f7-9298-cc107d9b361c.tiff
#   inflating: Cell_ROI_Images/1fd40774-5b99-458e-a67a-2cc854410ff0.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._1fd40774-5b99-458e-a67a-2cc854410ff0.tiff
#   inflating: Cell_ROI_Images/._1fd40774-5b99-458e-a67a-2cc854410ff0.tiff
#   inflating: Cell_ROI_Images/818a5ec0-591a-4d40-8418-580a4dae2039.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._818a5ec0-591a-4d40-8418-580a4dae2039.tiff
#   inflating: Cell_ROI_Images/._818a5ec0-591a-4d40-8418-580a4dae2039.tiff
#   inflating: Cell_ROI_Images/6bdd1818-1a09-4a81-8d6d-468d922eb06d.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._6bdd1818-1a09-4a81-8d6d-468d922eb06d.tiff
#   inflating: Cell_ROI_Images/._6bdd1818-1a09-4a81-8d6d-468d922eb06d.tiff
#   inflating: Cell_ROI_Images/441a2521-dd2a-495e-937d-b05fcca2da5d.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._441a2521-dd2a-495e-937d-b05fcca2da5d.tiff
#   inflating: Cell_ROI_Images/._441a2521-dd2a-495e-937d-b05fcca2da5d.tiff
#   inflating: Cell_ROI_Images/7964984d-a4f6-437e-93e5-a1e2c7b0d3d1.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._7964984d-a4f6-437e-93e5-a1e2c7b0d3d1.tiff
#   inflating: Cell_ROI_Images/._7964984d-a4f6-437e-93e5-a1e2c7b0d3d1.tiff
#   inflating: Cell_ROI_Images/4508b245-6a68-4e46-9e5d-256d1694ef11.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._4508b245-6a68-4e46-9e5d-256d1694ef11.tiff
#   inflating: Cell_ROI_Images/._4508b245-6a68-4e46-9e5d-256d1694ef11.tiff
#   inflating: Cell_ROI_Images/2b30da59-9f22-4a7b-b702-b4429889be6a.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._2b30da59-9f22-4a7b-b702-b4429889be6a.tiff
#   inflating: Cell_ROI_Images/._2b30da59-9f22-4a7b-b702-b4429889be6a.tiff
#   inflating: Cell_ROI_Images/d0bbc9fd-0bc6-450c-b774-54f593e97bce.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._d0bbc9fd-0bc6-450c-b774-54f593e97bce.tiff
#   inflating: Cell_ROI_Images/._d0bbc9fd-0bc6-450c-b774-54f593e97bce.tiff
#   inflating: Cell_ROI_Images/c06400eb-d265-4dd9-acb1-c386c777337e.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._c06400eb-d265-4dd9-acb1-c386c777337e.tiff
#   inflating: Cell_ROI_Images/._c06400eb-d265-4dd9-acb1-c386c777337e.tiff
#   inflating: Cell_ROI_Images/c39d9b7b-9ba5-49f5-8b28-1be8212e2c7c.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._c39d9b7b-9ba5-49f5-8b28-1be8212e2c7c.tiff
#   inflating: Cell_ROI_Images/._c39d9b7b-9ba5-49f5-8b28-1be8212e2c7c.tiff
#   inflating: Cell_ROI_Images/aa93e362-a429-4a1e-8854-ef3d21e28b5a.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._aa93e362-a429-4a1e-8854-ef3d21e28b5a.tiff
#   inflating: Cell_ROI_Images/._aa93e362-a429-4a1e-8854-ef3d21e28b5a.tiff
#   inflating: Cell_ROI_Images/0f97af90-05b0-4078-9fb4-5577fe0d19df.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._0f97af90-05b0-4078-9fb4-5577fe0d19df.tiff
#   inflating: Cell_ROI_Images/._0f97af90-05b0-4078-9fb4-5577fe0d19df.tiff
#   inflating: Cell_ROI_Images/03db83ce-87a3-40a0-ac16-5fab7798ad6e.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._03db83ce-87a3-40a0-ac16-5fab7798ad6e.tiff
#   inflating: Cell_ROI_Images/._03db83ce-87a3-40a0-ac16-5fab7798ad6e.tiff
#   inflating: Cell_ROI_Images/7ed06b93-0c05-42ba-9a6d-3885a1c1ca81.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._7ed06b93-0c05-42ba-9a6d-3885a1c1ca81.tiff
#   inflating: Cell_ROI_Images/._7ed06b93-0c05-42ba-9a6d-3885a1c1ca81.tiff
#   inflating: Cell_ROI_Images/54131b0f-7179-4ca6-b066-8cb4cd09d3a0.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._54131b0f-7179-4ca6-b066-8cb4cd09d3a0.tiff
#   inflating: Cell_ROI_Images/._54131b0f-7179-4ca6-b066-8cb4cd09d3a0.tiff
#   inflating: Cell_ROI_Images/a51171b9-ee9c-42ef-bdd0-10e8213a243c.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._a51171b9-ee9c-42ef-bdd0-10e8213a243c.tiff
#   inflating: Cell_ROI_Images/._a51171b9-ee9c-42ef-bdd0-10e8213a243c.tiff
#   inflating: Cell_ROI_Images/08b17b42-50dd-4ff1-ad0e-ef6eecd611bc.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._08b17b42-50dd-4ff1-ad0e-ef6eecd611bc.tiff
#   inflating: Cell_ROI_Images/._08b17b42-50dd-4ff1-ad0e-ef6eecd611bc.tiff
#   inflating: Cell_ROI_Images/3e5f4b3d-1862-4b39-b6ec-ca1d8ab676e7.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._3e5f4b3d-1862-4b39-b6ec-ca1d8ab676e7.tiff
#   inflating: Cell_ROI_Images/._3e5f4b3d-1862-4b39-b6ec-ca1d8ab676e7.tiff
#   inflating: Cell_ROI_Images/8710c3d3-0209-4f72-b9d5-e06d75f603a8.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._8710c3d3-0209-4f72-b9d5-e06d75f603a8.tiff
#   inflating: Cell_ROI_Images/._8710c3d3-0209-4f72-b9d5-e06d75f603a8.tiff
#   inflating: Cell_ROI_Images/fef8fbe6-536f-4f76-b550-7ae4be1ca6f4.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._fef8fbe6-536f-4f76-b550-7ae4be1ca6f4.tiff
#   inflating: Cell_ROI_Images/._fef8fbe6-536f-4f76-b550-7ae4be1ca6f4.tiff
#   inflating: Cell_ROI_Images/5e3a1feb-d44d-49b2-b031-76031c0116f1.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._5e3a1feb-d44d-49b2-b031-76031c0116f1.tiff
#   inflating: Cell_ROI_Images/._5e3a1feb-d44d-49b2-b031-76031c0116f1.tiff
#   inflating: Cell_ROI_Images/4f791af8-dfb1-4d41-afb6-01433f253051.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._4f791af8-dfb1-4d41-afb6-01433f253051.tiff
# ...
#   inflating: __MACOSX/Cell_ROI_Images/._151540b7-5717-4d30-b0ed-751a3ac8ee4c.tiff
#   inflating: Cell_ROI_Images/._151540b7-5717-4d30-b0ed-751a3ac8ee4c.tiff
#   inflating: Cell_ROI_Images/8d324083-80c8-4fca-badd-982aeb78cde7.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._8d324083-80c8-4fca-badd-982aeb78cde7.tiff
#   inflating: Cell_ROI_Images/._8d324083-80c8-4fca-badd-982aeb78cde7.tiff
#   inflating: Cell_ROI_Images/7f2f9152-35cf-4cc1-8ca5-167c49bfad69.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._7f2f9152-35cf-4cc1-8ca5-167c49bfad69.tiff
#   inflating: Cell_ROI_Images/._7f2f9152-35cf-4cc1-8ca5-167c49bfad69.tiff
#   inflating: Cell_ROI_Images/b8e92292-3d12-4fb2-829a-6a19d2986067.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._b8e92292-3d12-4fb2-829a-6a19d2986067.tiff
#   inflating: Cell_ROI_Images/._b8e92292-3d12-4fb2-829a-6a19d2986067.tiff
#   inflating: Cell_ROI_Images/620327f7-df9f-4c27-9fe9-e07fb6ff72c7.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._620327f7-df9f-4c27-9fe9-e07fb6ff72c7.tiff
#   inflating: Cell_ROI_Images/._620327f7-df9f-4c27-9fe9-e07fb6ff72c7.tiff
#   inflating: Cell_ROI_Images/a4b60c36-bfcb-4c10-bca9-60f3f07e3d5a.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._a4b60c36-bfcb-4c10-bca9-60f3f07e3d5a.tiff
#   inflating: Cell_ROI_Images/._a4b60c36-bfcb-4c10-bca9-60f3f07e3d5a.tiff
#   inflating: Cell_ROI_Images/a4529405-36a7-461f-bb54-4b37b80b249b.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._a4529405-36a7-461f-bb54-4b37b80b249b.tiff
#   inflating: Cell_ROI_Images/._a4529405-36a7-461f-bb54-4b37b80b249b.tiff
#   inflating: Cell_ROI_Images/36fca64f-a316-465d-a5d8-367b967649b6.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._36fca64f-a316-465d-a5d8-367b967649b6.tiff
#   inflating: Cell_ROI_Images/._36fca64f-a316-465d-a5d8-367b967649b6.tiff
#   inflating: Cell_ROI_Images/cc91128f-4e37-41b0-92e3-298692eb0202.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._cc91128f-4e37-41b0-92e3-298692eb0202.tiff
#   inflating: Cell_ROI_Images/._cc91128f-4e37-41b0-92e3-298692eb0202.tiff
#   inflating: Cell_ROI_Images/c8be33dc-843f-4694-86d6-5b1650b86096.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._c8be33dc-843f-4694-86d6-5b1650b86096.tiff
#   inflating: Cell_ROI_Images/._c8be33dc-843f-4694-86d6-5b1650b86096.tiff
#   inflating: Cell_ROI_Images/d5f632b5-b75a-4ddf-a7cf-285534480eb2.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._d5f632b5-b75a-4ddf-a7cf-285534480eb2.tiff
#   inflating: Cell_ROI_Images/._d5f632b5-b75a-4ddf-a7cf-285534480eb2.tiff
#   inflating: Cell_ROI_Images/cc750f26-501f-4f07-96a0-9237fa0f4804.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._cc750f26-501f-4f07-96a0-9237fa0f4804.tiff
#   inflating: Cell_ROI_Images/._cc750f26-501f-4f07-96a0-9237fa0f4804.tiff
#   inflating: Cell_ROI_Images/22cfca07-70ce-4cb3-ad3b-377de8c9db13.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._22cfca07-70ce-4cb3-ad3b-377de8c9db13.tiff
#   inflating: Cell_ROI_Images/._22cfca07-70ce-4cb3-ad3b-377de8c9db13.tiff
#   inflating: Cell_ROI_Images/0e215bec-15f1-4326-a0d8-ace8dcaaf012.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._0e215bec-15f1-4326-a0d8-ace8dcaaf012.tiff
#   inflating: Cell_ROI_Images/._0e215bec-15f1-4326-a0d8-ace8dcaaf012.tiff
#   inflating: Cell_ROI_Images/eafa147b-c258-4de0-bb65-b84171038aa9.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._eafa147b-c258-4de0-bb65-b84171038aa9.tiff
#   inflating: Cell_ROI_Images/._eafa147b-c258-4de0-bb65-b84171038aa9.tiff
#   inflating: Cell_ROI_Images/c3a38ef0-f9e4-4533-acf7-ce2636c26301.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._c3a38ef0-f9e4-4533-acf7-ce2636c26301.tiff
#   inflating: Cell_ROI_Images/._c3a38ef0-f9e4-4533-acf7-ce2636c26301.tiff
#   inflating: Cell_ROI_Images/d83ec72d-baf9-4d79-92b0-432b3521524e.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._d83ec72d-baf9-4d79-92b0-432b3521524e.tiff
#   inflating: Cell_ROI_Images/._d83ec72d-baf9-4d79-92b0-432b3521524e.tiff
#   inflating: Cell_ROI_Images/2f2d863a-1608-4cd9-a1a3-151f4d271ffc.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._2f2d863a-1608-4cd9-a1a3-151f4d271ffc.tiff
#   inflating: Cell_ROI_Images/._2f2d863a-1608-4cd9-a1a3-151f4d271ffc.tiff
#   inflating: Cell_ROI_Images/a406be00-0bb9-4559-8e62-3413b8864714.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._a406be00-0bb9-4559-8e62-3413b8864714.tiff
#   inflating: Cell_ROI_Images/._a406be00-0bb9-4559-8e62-3413b8864714.tiff
#   inflating: Cell_ROI_Images/eb1e0ce6-5a80-44c3-8a9e-32a2529cbb4e.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._eb1e0ce6-5a80-44c3-8a9e-32a2529cbb4e.tiff
#   inflating: Cell_ROI_Images/._eb1e0ce6-5a80-44c3-8a9e-32a2529cbb4e.tiff
#   inflating: Cell_ROI_Images/9128cbeb-b79a-4c71-b6c8-67483bd61570.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._9128cbeb-b79a-4c71-b6c8-67483bd61570.tiff
#   inflating: Cell_ROI_Images/._9128cbeb-b79a-4c71-b6c8-67483bd61570.tiff
#   inflating: Cell_ROI_Images/7f09e2cd-ee47-4fb4-9d04-12a5c582c3c2.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._7f09e2cd-ee47-4fb4-9d04-12a5c582c3c2.tiff
#   inflating: Cell_ROI_Images/._7f09e2cd-ee47-4fb4-9d04-12a5c582c3c2.tiff
#   inflating: Cell_ROI_Images/36b85e2c-606a-4e37-b507-b2c692ced3cf.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._36b85e2c-606a-4e37-b507-b2c692ced3cf.tiff
#   inflating: Cell_ROI_Images/._36b85e2c-606a-4e37-b507-b2c692ced3cf.tiff
#   inflating: Cell_ROI_Images/e367c47f-7028-433a-8725-b922f35e481d.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._e367c47f-7028-433a-8725-b922f35e481d.tiff
#   inflating: Cell_ROI_Images/._e367c47f-7028-433a-8725-b922f35e481d.tiff
#   inflating: Cell_ROI_Images/f5e3fe1c-ade2-41da-b22e-a903f842c01c.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._f5e3fe1c-ade2-41da-b22e-a903f842c01c.tiff
#   inflating: Cell_ROI_Images/._f5e3fe1c-ade2-41da-b22e-a903f842c01c.tiff
#   inflating: Cell_ROI_Images/57659151-49f5-4426-957a-bd6d49659b9a.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._57659151-49f5-4426-957a-bd6d49659b9a.tiff
#   inflating: Cell_ROI_Images/._57659151-49f5-4426-957a-bd6d49659b9a.tiff
#   inflating: Cell_ROI_Images/21f122f3-e13d-4674-8230-6af205dbf303.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._21f122f3-e13d-4674-8230-6af205dbf303.tiff
#   inflating: Cell_ROI_Images/._21f122f3-e13d-4674-8230-6af205dbf303.tiff
#   inflating: Cell_ROI_Images/f6033344-0ffd-4866-a5e3-30dae0d47c07.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._f6033344-0ffd-4866-a5e3-30dae0d47c07.tiff
#   inflating: Cell_ROI_Images/._f6033344-0ffd-4866-a5e3-30dae0d47c07.tiff
#   inflating: Cell_ROI_Images/eab18f00-b0f2-4d1f-9aaa-a2fc8ab14d32.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._eab18f00-b0f2-4d1f-9aaa-a2fc8ab14d32.tiff
#   inflating: Cell_ROI_Images/._eab18f00-b0f2-4d1f-9aaa-a2fc8ab14d32.tiff
#   inflating: Cell_ROI_Images/c39d805a-e3ac-4f63-9fd4-13dd2d383193.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._c39d805a-e3ac-4f63-9fd4-13dd2d383193.tiff
#   inflating: Cell_ROI_Images/._c39d805a-e3ac-4f63-9fd4-13dd2d383193.tiff
#   inflating: Cell_ROI_Images/f08d58c1-2e37-47e7-acac-e4dbc45fd20d.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._f08d58c1-2e37-47e7-acac-e4dbc45fd20d.tiff
#   inflating: Cell_ROI_Images/._f08d58c1-2e37-47e7-acac-e4dbc45fd20d.tiff
#   inflating: Cell_ROI_Images/95b949ff-4f9e-4ea6-8d0d-a8dc6db60306.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._95b949ff-4f9e-4ea6-8d0d-a8dc6db60306.tiff
#   inflating: Cell_ROI_Images/._95b949ff-4f9e-4ea6-8d0d-a8dc6db60306.tiff
#   inflating: Cell_ROI_Images/86beb64b-97c6-4c94-9275-4751cbf37c58.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._86beb64b-97c6-4c94-9275-4751cbf37c58.tiff
#   inflating: Cell_ROI_Images/._86beb64b-97c6-4c94-9275-4751cbf37c58.tiff
#   inflating: Cell_ROI_Images/ea0991cf-2c50-4f92-8121-850ebd358151.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._ea0991cf-2c50-4f92-8121-850ebd358151.tiff
#   inflating: Cell_ROI_Images/._ea0991cf-2c50-4f92-8121-850ebd358151.tiff
#   inflating: Cell_ROI_Images/da4e11c3-fd50-4503-b67f-48c4b2064812.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._da4e11c3-fd50-4503-b67f-48c4b2064812.tiff
#   inflating: Cell_ROI_Images/._da4e11c3-fd50-4503-b67f-48c4b2064812.tiff
#   inflating: Cell_ROI_Images/ac3407c5-e16d-40ad-bf01-56cdbbb82c07.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._ac3407c5-e16d-40ad-bf01-56cdbbb82c07.tiff
#   inflating: Cell_ROI_Images/._ac3407c5-e16d-40ad-bf01-56cdbbb82c07.tiff
#   inflating: Cell_ROI_Images/7ea1b74c-8646-412d-8427-cc3be47f437f.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._7ea1b74c-8646-412d-8427-cc3be47f437f.tiff
#   inflating: Cell_ROI_Images/._7ea1b74c-8646-412d-8427-cc3be47f437f.tiff
#   inflating: Cell_ROI_Images/c924bba1-f76f-4812-a504-eabebc396f00.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._c924bba1-f76f-4812-a504-eabebc396f00.tiff
#   inflating: Cell_ROI_Images/._c924bba1-f76f-4812-a504-eabebc396f00.tiff
#   inflating: Cell_ROI_Images/44af72a9-edf3-4420-99da-d53ca0e635c6.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._44af72a9-edf3-4420-99da-d53ca0e635c6.tiff
#   inflating: Cell_ROI_Images/._44af72a9-edf3-4420-99da-d53ca0e635c6.tiff
#   inflating: Cell_ROI_Images/3fb4d966-2879-4055-80c4-e36c6279d1d2.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._3fb4d966-2879-4055-80c4-e36c6279d1d2.tiff
#   inflating: Cell_ROI_Images/._3fb4d966-2879-4055-80c4-e36c6279d1d2.tiff
#   inflating: Cell_ROI_Images/ac12c1be-77be-4f2c-8fcb-4093e4da4469.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._ac12c1be-77be-4f2c-8fcb-4093e4da4469.tiff
#   inflating: Cell_ROI_Images/._ac12c1be-77be-4f2c-8fcb-4093e4da4469.tiff
#   inflating: Cell_ROI_Images/5fc0911f-bb54-4fad-8596-6061ae597aa6.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._5fc0911f-bb54-4fad-8596-6061ae597aa6.tiff
#   inflating: Cell_ROI_Images/._5fc0911f-bb54-4fad-8596-6061ae597aa6.tiff
#   inflating: Cell_ROI_Images/3a3d55cc-99ca-435f-8e3c-3e3c3570f90b.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._3a3d55cc-99ca-435f-8e3c-3e3c3570f90b.tiff
#   inflating: Cell_ROI_Images/._3a3d55cc-99ca-435f-8e3c-3e3c3570f90b.tiff
#   inflating: Cell_ROI_Images/be8e8198-eac0-4d88-995e-2fe1218b237b.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._be8e8198-eac0-4d88-995e-2fe1218b237b.tiff
#   inflating: Cell_ROI_Images/._be8e8198-eac0-4d88-995e-2fe1218b237b.tiff
#   inflating: Cell_ROI_Images/87add741-095e-4657-9b4b-b3bb2dee92cc.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._87add741-095e-4657-9b4b-b3bb2dee92cc.tiff
#   inflating: Cell_ROI_Images/._87add741-095e-4657-9b4b-b3bb2dee92cc.tiff
#   inflating: Cell_ROI_Images/484e0cc6-4bc9-403a-ab4f-a88048878b1f.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._484e0cc6-4bc9-403a-ab4f-a88048878b1f.tiff
#   inflating: Cell_ROI_Images/._484e0cc6-4bc9-403a-ab4f-a88048878b1f.tiff
#   inflating: Cell_ROI_Images/1f0f22b4-f85c-4bbc-9408-92ecc610dece.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._1f0f22b4-f85c-4bbc-9408-92ecc610dece.tiff
#   inflating: Cell_ROI_Images/._1f0f22b4-f85c-4bbc-9408-92ecc610dece.tiff
#   inflating: Cell_ROI_Images/5e7fb16b-0816-49c5-9d77-668f5d3be373.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._5e7fb16b-0816-49c5-9d77-668f5d3be373.tiff
#   inflating: Cell_ROI_Images/._5e7fb16b-0816-49c5-9d77-668f5d3be373.tiff
#   inflating: Cell_ROI_Images/f47b2588-406e-4fa8-bcd0-ecd081bb8d72.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._f47b2588-406e-4fa8-bcd0-ecd081bb8d72.tiff
#   inflating: Cell_ROI_Images/._f47b2588-406e-4fa8-bcd0-ecd081bb8d72.tiff
#   inflating: Cell_ROI_Images/8c7f7c0a-f857-4b21-a635-6df80d8129f2.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._8c7f7c0a-f857-4b21-a635-6df80d8129f2.tiff
#   inflating: Cell_ROI_Images/._8c7f7c0a-f857-4b21-a635-6df80d8129f2.tiff
#   inflating: Cell_ROI_Images/32138438-e112-40eb-bba0-86132c4a6a65.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._32138438-e112-40eb-bba0-86132c4a6a65.tiff
#   inflating: Cell_ROI_Images/._32138438-e112-40eb-bba0-86132c4a6a65.tiff
#   inflating: Cell_ROI_Images/258375e9-b72d-49f0-8ef9-9aa6e57beef9.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._258375e9-b72d-49f0-8ef9-9aa6e57beef9.tiff
#   inflating: Cell_ROI_Images/._258375e9-b72d-49f0-8ef9-9aa6e57beef9.tiff
#   inflating: Cell_ROI_Images/7aaaf63f-527a-4f82-bb9e-f0c3d142927f.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._7aaaf63f-527a-4f82-bb9e-f0c3d142927f.tiff
#   inflating: Cell_ROI_Images/._7aaaf63f-527a-4f82-bb9e-f0c3d142927f.tiff
#   inflating: Cell_ROI_Images/fd3cdf0e-f1d5-4f5e-beb6-555129f7264c.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._fd3cdf0e-f1d5-4f5e-beb6-555129f7264c.tiff
#   inflating: Cell_ROI_Images/._fd3cdf0e-f1d5-4f5e-beb6-555129f7264c.tiff
#   inflating: Cell_ROI_Images/17a1edca-5ed5-4333-8549-b37702631ab3.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._17a1edca-5ed5-4333-8549-b37702631ab3.tiff
#   inflating: Cell_ROI_Images/._17a1edca-5ed5-4333-8549-b37702631ab3.tiff
#   inflating: Cell_ROI_Images/a2d14bcd-9312-4514-a148-87b49b5f4388.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._a2d14bcd-9312-4514-a148-87b49b5f4388.tiff
#   inflating: Cell_ROI_Images/._a2d14bcd-9312-4514-a148-87b49b5f4388.tiff
#   inflating: Cell_ROI_Images/a587994b-3618-4008-aead-a5097bffd8c6.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._a587994b-3618-4008-aead-a5097bffd8c6.tiff
#   inflating: Cell_ROI_Images/._a587994b-3618-4008-aead-a5097bffd8c6.tiff
#   inflating: Cell_ROI_Images/efb6b926-462c-4de4-8ba7-3609e96e2c9b.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._efb6b926-462c-4de4-8ba7-3609e96e2c9b.tiff
#   inflating: Cell_ROI_Images/._efb6b926-462c-4de4-8ba7-3609e96e2c9b.tiff
#   inflating: Cell_ROI_Images/6fcc9807-17e3-4fb2-bb88-af8333144d1f.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._6fcc9807-17e3-4fb2-bb88-af8333144d1f.tiff
#   inflating: Cell_ROI_Images/._6fcc9807-17e3-4fb2-bb88-af8333144d1f.tiff
#   inflating: Cell_ROI_Images/f0b4438f-942e-4e62-a09a-7717c557b58d.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._f0b4438f-942e-4e62-a09a-7717c557b58d.tiff
#   inflating: Cell_ROI_Images/._f0b4438f-942e-4e62-a09a-7717c557b58d.tiff
#   inflating: Cell_ROI_Images/64475a5d-f639-4c85-a6a1-3e1ef7b29ee1.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._64475a5d-f639-4c85-a6a1-3e1ef7b29ee1.tiff
#   inflating: Cell_ROI_Images/._64475a5d-f639-4c85-a6a1-3e1ef7b29ee1.tiff
#   inflating: Cell_ROI_Images/7ec93ea1-8718-4563-84aa-5ad1d26b29b5.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._7ec93ea1-8718-4563-84aa-5ad1d26b29b5.tiff
#   inflating: Cell_ROI_Images/._7ec93ea1-8718-4563-84aa-5ad1d26b29b5.tiff
#   inflating: Cell_ROI_Images/5afaccc8-50b4-4f02-a597-c7a23d8ab5de.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._5afaccc8-50b4-4f02-a597-c7a23d8ab5de.tiff
#   inflating: Cell_ROI_Images/._5afaccc8-50b4-4f02-a597-c7a23d8ab5de.tiff
#   inflating: Cell_ROI_Images/1cb85177-5e98-416e-ae01-12d1cf0c45e6.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._1cb85177-5e98-416e-ae01-12d1cf0c45e6.tiff
#   inflating: Cell_ROI_Images/._1cb85177-5e98-416e-ae01-12d1cf0c45e6.tiff
#   inflating: Cell_ROI_Images/0ce08963-989f-44f0-9fdd-2abc37a21407.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._0ce08963-989f-44f0-9fdd-2abc37a21407.tiff
#   inflating: Cell_ROI_Images/._0ce08963-989f-44f0-9fdd-2abc37a21407.tiff
#   inflating: Cell_ROI_Images/81ff10ba-f480-40be-af4a-4b99e3f7d048.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._81ff10ba-f480-40be-af4a-4b99e3f7d048.tiff
#   inflating: Cell_ROI_Images/._81ff10ba-f480-40be-af4a-4b99e3f7d048.tiff
#   inflating: Cell_ROI_Images/0b48eda6-a577-45d2-81de-b11fb6691dd2.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._0b48eda6-a577-45d2-81de-b11fb6691dd2.tiff
#   inflating: Cell_ROI_Images/._0b48eda6-a577-45d2-81de-b11fb6691dd2.tiff
#   inflating: Cell_ROI_Images/da61d881-4f5b-40b6-9e99-e5ca30c4d64a.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._da61d881-4f5b-40b6-9e99-e5ca30c4d64a.tiff
#   inflating: Cell_ROI_Images/._da61d881-4f5b-40b6-9e99-e5ca30c4d64a.tiff
#   inflating: Cell_ROI_Images/1e3298bd-ab06-46fb-bb9e-16fd230e8ece.tiff
#   inflating: __MACOSX/Cell_ROI_Images/._1e3298bd-ab06-46fb-bb9e-16fd230e8ece.tiff
#   inflating: Cell_ROI_Images/._1e3298bd-ab06-46fb-bb9e-16fd230e8ece.tiff

# %%
# define the number of channels in the input, number of classes,
# and number of levels in the U-Net model
channel_count = 1 #Since everything is black and white. Channel here refers to colors (like RGB)
class_count = 3 #This will be modified, but let's start off with the canonical three.
# levels_count = 3 #I'm not sure what this refers to

# initialize learning rate, number of epochs to train for, and the
# batch size
learning_rate = 0.001
epoch_count = 1
batch_size = 30

# define the input image dimensions. Images are square
image_dimensions = 256

#Use a GPU if available, otherwise use a CPU
device_type = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(f"Using {device_type} for calculations")

# determine if we will be pinning memory during data loading
pin_memory_status = True if device_type == "cuda" else False
# Out:
# Using cpu for calculations

# %%
data_directory_path = 'Cell_ROI_Images'

# %% [markdown]
# ## Read in and Process Data

# %% [markdown]
# #### Using Pytorch

# %%
class NPM1_Pol1_Dataset(Dataset):

    def __init__(self, root_dir, transform=None):
        """
        Arguments:
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.root_dir = root_dir
        self.transform = transform

        self.list_of_files=glob.glob(f"{self.root_dir}/*.tiff")

    def __len__(self):
        return len(self.list_of_files)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        image = io.imread(self.list_of_files[idx])
        #Only select images that are large enough
        # if image[0].shape[0] >= image_dimensions and image[0].shape[1] >= image_dimensions:
          #NPM1 image is in slice 0, and Pol1 is in slice 1
        sample = {'npm1_image': image[0],
                  'pol1_image': image[1],
                  'file_name':self.list_of_files[idx].split("/")[-1]}

        if self.transform:
            sample = self.transform(sample)

        return sample

# %%
#Functions to process images
class StrategicCrop(object):
    """Crop the image in a sample to retain as much intensity.

    Args:
        output_size (tuple or int): Desired output size. If int, square crop
            is made.
    """

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        if isinstance(output_size, int):
            self.output_size = (output_size, output_size)
        else:
            assert len(output_size) == 2
            self.output_size = output_size

    def __call__(self, sample):
        npm1_image, pol1_image, file_names = sample['npm1_image'], sample['pol1_image'], sample['file_name']
        h, w = npm1_image.shape[:2]

        # Ensure the image is large enough for cropping
        if h < self.output_size[0] or w < self.output_size[1]:
            return None

        new_h, new_w = self.output_size
        max_intensity = -np.inf
        best_crop_coords = None

        # Slide a window of crop_size over the entire image
        for i in range(h - new_h + 1):
            for j in range(w - new_w + 1):
                # Define the crop region
                region = npm1_image[i:i + new_h, j:j + new_w]
                # Compute the sum of intensities of the region
                region_intensity = np.sum(region)
                # If this region has a higher intensity sum, store it
                if region_intensity > max_intensity:
                    max_intensity = region_intensity
                    best_crop_coords = (i, j)

        if best_crop_coords is None:
            return None

        i, j = best_crop_coords

        # Apply the same crop to both images
        npm1_crop = npm1_image[i:i + new_h, j:j + new_w]
        pol1_crop = pol1_image[i:i + new_h, j:j + new_w]

        return {'npm1_image': npm1_crop, 'pol1_image': pol1_crop, 'file_name': file_names}

class RandomCrop(object):
    """Crop randomly the image in a sample.

    Args:
        output_size (tuple or int): Desired output size. If int, square crop
            is made.
    """

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        if isinstance(output_size, int):
            self.output_size = (output_size, output_size)
        else:
            assert len(output_size) == 2
            self.output_size = output_size

    def __call__(self, sample):
        npm1_image, pol1_image, file_names = sample['npm1_image'], sample['pol1_image'], sample['file_name']

        h, w = npm1_image.shape[:2]
        new_h, new_w = self.output_size
        try:
          top = np.random.randint(0, h - new_h + 1)
          left = np.random.randint(0, w - new_w + 1)

          npm1_image = npm1_image[top: top + new_h,
                        left: left + new_w]
          pol1_image = pol1_image[top: top + new_h,
                        left: left + new_w]
        except:
          #Print out names of files that cannot be cropped (likely too small)
          print(file_names)

        return {'npm1_image': npm1_image,
                'pol1_image': pol1_image,
                'file_name': file_names}

class Normalize(object):
    """Normalize Images"""
    def __call__(self, sample):
      npm1_image, pol1_image, file_names = sample['npm1_image'], sample['pol1_image'], sample['file_name']

      #Set all values below zero to zero (this might be an abberation from FF correction)
      npm1_image[npm1_image<0]=0
      mean_npm1_value=np.mean(npm1_image)
      std_npm1_value=np.std(npm1_image)
      normalized_npm1_image=(npm1_image-mean_npm1_value)/std_npm1_value

      #Set all values below zero to zero (this might be an abberation from FF correction)
      pol1_image[pol1_image<0]=0
      mean_pol1_value=np.mean(pol1_image)
      std_pol1_value=np.std(pol1_image)
      normalized_pol1_image=(pol1_image-mean_pol1_value)/std_pol1_value

      return {'npm1_image': normalized_npm1_image,
              'pol1_image': normalized_pol1_image,
              'file_name': file_names}


class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""
		#Images need to be reshaped into 3D tensors for UNET. The first dimension
		#is the channel count. This is set to one here as a dummy dimension.
    def __call__(self, sample):
        npm1_image, pol1_image, file_names = sample['npm1_image'], sample['pol1_image'], sample['file_name']
        return {'npm1_image': torch.unsqueeze(torch.from_numpy(npm1_image),0),
                'pol1_image': torch.unsqueeze(torch.from_numpy(pol1_image),0),
                'file_name': file_names}

# %%
# remove files that are too small for cropping

allpaths = glob.glob(f"{data_directory_path}/*.tiff")

print("before:", len(allpaths))
for image_file in allpaths:
  image = io.imread(image_file)
  if image[0].shape[0] < image_dimensions or image[0].shape[1] < image_dimensions:
    # !rm {image_file}
print("after:", len(glob.glob(f"{data_directory_path}/*.tiff")))

# 754 files --> 703 files
# Out:
# before: 754
# after: 703

# %%
print("trainingset:", len(os.listdir(f"{data_directory_path}/Training_Set")))
print("validation set:", len(os.listdir(f"{data_directory_path}/Validation_Set")))
# Out:
# trainingset: 217
# validation set: 108

# %%
#Generate strategic crops of same size of images and convert to tensors
data_transforms = {
    'Training_Set': torchvision.transforms.Compose([
        Normalize(),
        StrategicCrop(image_dimensions), #Need to change this to crop around a region with high intensity
        # torchvision.transforms.RandomHorizontalFlip(),
        ToTensor()
        ]),
    'Validation_Set': torchvision.transforms.Compose([
        Normalize(),
        RandomCrop(image_dimensions),#Need to change this to crop around a region with high intensity
        # torchvision.transforms.RandomHorizontalFlip(),
        ToTensor()
        ])}

#Set up training and validation directories
if len(glob.glob(f'{data_directory_path}/*.tiff'))!= 0: #check if you haven't already split the dataonce before
  train_paths, test_paths = train_test_split(glob.glob(f'{data_directory_path}/*.tiff'), test_size=0.33, random_state=42)
  # !mkdir Cell_ROI_Images/Training_Set
  # !mkdir Cell_ROI_Images/Validation_Set
  for path in train_paths:
    destination = os.path.join(data_directory_path, "Training_Set", os.path.basename(path))
    # !mv {path} {destination}
  for path in test_paths:
    destination = os.path.join(data_directory_path, "Validation_Set", os.path.basename(path))
    # !mv {path} {destination}
print("for record keeping: ")
print("Files in training set:", len(os.listdir(f"{data_directory_path}/Training_Set")))
print("Files in validation set:", len(os.listdir(f"{data_directory_path}/Validation_Set")))

#Create dataset
image_datasets = {x: NPM1_Pol1_Dataset(root_dir=os.path.join(data_directory_path,x), transform=data_transforms[x]) for x in ['Training_Set', 'Validation_Set']}

#Upload the transformed dataset to Dataloader iterator
dataloaders = {x: DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True,pin_memory=pin_memory_status,num_workers=os.cpu_count())
              for x in ['Training_Set', 'Validation_Set']}
# Out:
# for record keeping:
# Files in training set: 217
# Files in validation set: 108

# %% [markdown]
# ### Building the U-Net Architecture

# %%
class Block(nn.Module):
	def __init__(self, inChannels, outChannels):
		super().__init__()
		# store the convolution and RELU layers
		#The kernal size should not be 1 (third argument) (consistent with U-Net architecture)
    #Using padding=1 to maintain image dimensions
		self.conv1 = nn.Conv2d(inChannels, outChannels, kernel_size=3, padding=1)
		self.relu = nn.ReLU()
		# #The kernal size should not be 1 (third argument) (consistent with U-Net architecture)
    #Using padding=1 to maintain image dimensions
		self.conv2 = nn.Conv2d(outChannels, outChannels, kernel_size=3, padding=1)
    # Pooling acts as a sort of spatial dimensional reduction.
		# self.pool = nn.MaxPool2d(kernel_size=3,stride=1)
	def forward(self, x):
		## apply CONV => RELU => CONV block to the inputs and return it
		# apply CONV => RELU => POOL block to the inputs and return it
    #ReLU will clip the smallest value of inputs to be >=0.
		return self.relu(self.conv2(self.relu(self.conv1(x))))

# %%
class Encoder(nn.Module):
	def __init__(self, channels=(1, 16, 32, 64, 128)): #The first argument here is the number of channels in our image.
		super().__init__()
		# store the encoder blocks and maxpooling layer
		self.encBlocks = nn.ModuleList(
			[Block(channels[i], channels[i + 1])
			 	for i in range(len(channels) - 1)])
    #The maxpooling layer will reduce the size of the data by half.
    #This acts as a sort of spatial dimensional reduction.
		# self.pool = nn.MaxPool2d(2)

	def forward(self, x):
		# initialize an empty list to store the intermediate outputs
		blockOutputs = []
		# loop through the encoder blocks
		for block in self.encBlocks:
			# pass the inputs through the current encoder block, store
			# the outputs, and then apply maxpooling on the output
			x = block(x)
			# print("The dimensions after conv pixels: ")
			# print(x.shape)
			blockOutputs.append(x)
			# x = self.pool(x) #Removing pooling for now

		# return the list containing the intermediate outputs
		return blockOutputs

# %%
class Decoder(nn.Module):
	def __init__(self, channels=(128, 64, 32, 16)):
		super().__init__()
		# initialize the number of channels, upsampler blocks, and
		# decoder blocks
		self.channels = channels
		self.upconvs = nn.ModuleList(
      #Using padding=1 to maintain image dimensions
			[nn.ConvTranspose2d(channels[i], channels[i + 1], kernel_size=3,padding=1)
			 	for i in range(len(channels) - 1)])
		self.dec_blocks = nn.ModuleList(
			[Block(channels[i], channels[i + 1])
			 	for i in range(len(channels) - 1)])

	def forward(self, x, encFeatures):
		# loop through the number of channels
		for i in range(len(self.channels) - 1):
			# pass the inputs through the upsampler blocks
			x = self.upconvs[i](x)
			# print("The dimensions after upconv pixels: ")
			# print(x.shape)
      #Implementing skip connections now
			# crop the current features from the encoder blocks,
			# concatenate them with the current upsampled features,
			# and pass the concatenated output through the current
			# decoder block
			encFeat = self.crop(encFeatures[i], x)
			x = torch.cat([x, encFeat], dim=1)
			x = self.dec_blocks[i](x)
			# print("The dimensions after deconv channels: ")
			# print(x.shape)
		# return the final decoder output
		return x

	def crop(self, encFeatures, x):
		# grab the dimensions of the inputs, and crop the encoder
		# features to match the dimensions
		(_, _, H, W) = x.shape
		encFeatures = torchvision.transforms.CenterCrop([H, W])(encFeatures)
		# return the cropped features
		return encFeatures

# %%
class UNet(nn.Module):
	#For Josh's Mathematica code: encChannels=(1, 64, 128, 256)
	def __init__(self, encChannels=(1, 16, 32, 64, 128, 256), #The first argument here is the number of channels in our image.
		 decChannels=(256, 128, 64, 32, 16),
		 nbClasses=class_count, retainDim=False, #nbClasses refers to the number of segmentation classes possible.
		 outSize=(image_dimensions,  image_dimensions)):
		super().__init__()
		# initialize the encoder and decoder
		self.encoder = Encoder(encChannels)
		self.decoder = Decoder(decChannels)
		# initialize the regression head and store the class variables
		self.head = nn.Conv2d(decChannels[-1], nbClasses, 1)
		self.retainDim = retainDim
		self.outSize = outSize

	def forward(self, x):
			# grab the features from the encoder
			encFeatures = self.encoder(x)
			# pass the encoder features through decoder making sure that
			# their dimensions are suited for concatenation
			decFeatures = self.decoder(encFeatures[::-1][0],
				encFeatures[::-1][1:])
			# pass the decoder features through the regression head to
			# obtain the segmentation mask
			map = self.head(decFeatures)
			# check to see if we are retaining the original output
			# dimensions and if so, then resize the output to match them
			if self.retainDim:
				map = nn.functional.interpolate(map, self.outSize)
			#Normalize all channel values associated with a single pixel to equal one.
			m = nn.Softmax(dim=1)
			normalized_map = m(map)
			# return the segmentation map
			return normalized_map

# %% [markdown]
# ### Extract Compartment Concentrations and Recapitulate Image of Protein B

# %%
def calculate_compartment_concentrations(predicted_compartment_batch_tensor,other_protein_image_batch_tensor):
  #Images are organized as a batch.
  #Work on optimizing these operations
  for (n,predicted_compartment_tensor) in enumerate(predicted_compartment_batch_tensor):
    converted_predicted_compartment_tensor=predicted_compartment_tensor.cpu().clone().detach().numpy()
    #Define the matrix of average compartments values
    averaged_compartment_fraction_matrix=np.zeros((class_count,class_count))
    for i in range(class_count):
      #Extract nxn matrix associated with compartment
      column_selected_compartment_fraction_matrix=np.squeeze(converted_predicted_compartment_tensor[i,:,:])
      for j in range(class_count):
        #Extract nxn matrix associated with compartment
        row_selected_compartment_fraction_matrix=np.squeeze(converted_predicted_compartment_tensor[j,:,:])
        #Multiply the matrices then take average over all pixels
        #Need to do element wise multiplication not matrix multiplication (since each pixel is independent)
        multiplied_matrix=np.multiply(column_selected_compartment_fraction_matrix, row_selected_compartment_fraction_matrix)
        average_pixel_value=np.mean(multiplied_matrix)
        averaged_compartment_fraction_matrix[i,j]=average_pixel_value
    #Take the inverse of the matrix
    inverted_averaged_compartment_fraction_matrix=np.linalg.inv(averaged_compartment_fraction_matrix)
    ###
    #Extract nxn matrix associated with other protein's image matrix.
    other_protein_image_matrix=np.squeeze(other_protein_image_batch_tensor[n,:,:,:].cpu().clone().detach().numpy())
    #Define vector of averaged scaled intensity values
    averaged_scaled_intensity_vector=[]
    for k in range(class_count):
      #Extract nxn matrix associated with compartment
      column_selected_compartment_fraction_matrix=np.squeeze(converted_predicted_compartment_tensor[k,:,:])
      #Multiply the matrices than average over all pixels
      #Need to do element wise multiplication not matrix multiplication (since each pixel is independent)
      multiplied_matrix=np.multiply(column_selected_compartment_fraction_matrix,other_protein_image_matrix)
      average_pixel_value=np.mean(multiplied_matrix)
      averaged_scaled_intensity_vector.append(average_pixel_value)

    averaged_scaled_intensity_vector=np.asarray(averaged_scaled_intensity_vector)

    #Multiply the vector with the inverted matrix
    concentration_vector=np.matmul(averaged_scaled_intensity_vector,inverted_averaged_compartment_fraction_matrix)
    #Setting concentration values to zero and above to be physical.
    concentration_vector[concentration_vector<0]=0
    ###
    #Recapitulate the image of the other protein
    compartment_fraction_matrix=np.squeeze(converted_predicted_compartment_tensor)

    recapitulated_other_protein_image_matrix=np.dot(np.moveaxis(compartment_fraction_matrix, 0, -1),concentration_vector)
    ###
    #Gather calculated values into tensors
    concentration_values_tensor=torch.tensor(concentration_vector,requires_grad=True,dtype=float)
    reformated_concentration_values_tensor=torch.unsqueeze(concentration_values_tensor,0)

    other_protein_image_tensor=torch.tensor(other_protein_image_matrix,requires_grad=True,dtype=float)
    reformated_other_protein_image_tensor=torch.unsqueeze(other_protein_image_tensor,0)

    recapitulated_other_protein_image_tensor=torch.tensor(recapitulated_other_protein_image_matrix,requires_grad=True,dtype=float)
    reformated_recapitulated_other_protein_image_tensor=torch.unsqueeze(recapitulated_other_protein_image_tensor,0)

    #Constructing the output:
    if n==0:
      concentration_values_batch_tensor=reformated_concentration_values_tensor
      new_other_protein_image_batch_tensor=reformated_other_protein_image_tensor
      recapitulated_other_protein_image_batch_tensor=reformated_recapitulated_other_protein_image_tensor
    else:
      concentration_values_batch_tensor=torch.cat((concentration_values_batch_tensor,reformated_concentration_values_tensor),0)
      new_other_protein_image_batch_tensor=torch.cat((new_other_protein_image_batch_tensor,reformated_other_protein_image_tensor),0)
      recapitulated_other_protein_image_batch_tensor=torch.cat((recapitulated_other_protein_image_batch_tensor,reformated_recapitulated_other_protein_image_tensor),0)

  return concentration_values_batch_tensor, new_other_protein_image_batch_tensor, recapitulated_other_protein_image_batch_tensor

# %% [markdown]
# ### Training the U-Net

# %%
# initialize our UNet model
unet = UNet().to(device_type)
# initialize loss function and optimizer
lossFunc = nn.MSELoss()

opt = optim.Adam(unet.parameters(), lr=learning_rate)
# calculate steps per epoch for training and test set
trainSteps = len(image_datasets["Training_Set"]) // batch_size
validSteps = len(image_datasets["Validation_Set"]) // batch_size
# initialize a dictionary to store training history
H = {"train_loss": [], "validation_loss": []}

# %%
unet
# Out:
# UNet(
#   (encoder): Encoder(
#     (encBlocks): ModuleList(
#       (0): Block(
#         (conv1): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU()
#         (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (1): Block(
#         (conv1): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU()
#         (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (2): Block(
#         (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU()
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (3): Block(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU()
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (4): Block(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU()
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (decoder): Decoder(
#     (upconvs): ModuleList(
#       (0): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (2): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (dec_blocks): ModuleList(
#       (0): Block(
#         (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU()
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (1): Block(
#         (conv1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU()
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (2): Block(
#         (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU()
#         (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (3): Block(
#         (conv1): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU()
#         (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (head): Conv2d(16, 3, kernel_size=(1, 1), stride=(1, 1))
# )

# %% [markdown]
# ### Run Over All Data

# %%
# loop over epochs
print("[INFO] training the network...")
startTime = time.time()
for e in tqdm(range(epoch_count)):
	# set the model in training mode
	unet.train()
	# initialize the total training and validation loss
	total_training_loss = 0
	total_validation_loss = 0
	# loop over the training set
	for (i, x) in enumerate(dataloaders["Training_Set"]):
		# send the input to the device
		npm1_image_tensor = x["npm1_image"].to(device_type)
		pol1_image_tensor= x["pol1_image"].to(device_type)

		# perform a forward pass and calculate the training loss
		#Compartments are predicted
		predicted_compartment_tensor = unet(npm1_image_tensor)
		#Extract predicted compartments' concentrations
		concentration_values_batch_tensor, new_other_protein_image_batch_tensor, recapitulated_other_protein_image_batch_tensor=calculate_compartment_concentrations(predicted_compartment_tensor,pol1_image_tensor)

		#"requires_grad=True" is necessary to keep track of the gradients
		#I have to specify the dtype as function was previously producing dtype=double
		training_loss = lossFunc(recapitulated_other_protein_image_batch_tensor,
		                         new_other_protein_image_batch_tensor)

		# first, zero out any previously accumulated gradients, then
		# perform backpropagation, and then update model parameters
		opt.zero_grad()
		training_loss.backward()
		opt.step() #This initiates gradient descent
		# add the loss to the total training loss so far
		total_training_loss += training_loss

		# switch off autograd
		with torch.no_grad():
			# set the model in evaluation mode
			unet.eval()
			# loop over the validation set
			for (j, y) in enumerate(dataloaders["Validation_Set"]):
				# send the input to the device
				npm1_image_tensor = y["npm1_image"].to(device_type)
				pol1_image_tensor= y["pol1_image"].to(device_type)

				# perform a forward pass and calculate the training loss
				#Compartments are predicted
				predicted_compartment_tensor = unet(npm1_image_tensor)
				#Extract predicted compartments' concentrations
				concentration_values_batch_tensor, new_other_protein_image_batch_tensor, recapitulated_other_protein_image_batch_tensor=calculate_compartment_concentrations(predicted_compartment_tensor,pol1_image_tensor)

				#"requires_grad=True" is necessary to keep track of the gradients
				#I have to specify the dtype as function was previously producing dtype=double
				validation_loss = lossFunc(recapitulated_other_protein_image_batch_tensor,
				                           new_other_protein_image_batch_tensor)
				total_validation_loss += validation_loss

		# calculate the average training and validation loss
		average_training_loss = total_training_loss / trainSteps
		average_validation_loss = total_validation_loss / validSteps
		# update our training history
		H["train_loss"].append(average_training_loss.cpu().detach().numpy())
		H["validation_loss"].append(average_validation_loss.cpu().detach().numpy())
		# print the model training and validation information
		print("[INFO] EPOCH: {}/{}".format(e + 1, epoch_count))
		# print("Train loss: {:.6f}, Validation loss: {:.4f}".format(
		# 	average_training_loss, average_validation_loss))
		print("Train loss: {:.6f}, Validation loss: {:.4f}".format(
			training_loss, validation_loss))
	# display the total time needed to perform the training
	endTime = time.time()
	print("[INFO] total time taken to train the model: {:.2f}s".format(
		endTime - startTime))
# Out:
# [INFO] training the network...
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
fig,axes=plt.subplots(1,6,figsize=(20,10))

axes[0].imshow(np.squeeze((npm1_image_tensor.cpu().clone().detach().numpy())[0,:,:]))
axes[1].imshow(np.squeeze((pol1_image_tensor.cpu().clone().detach().numpy())[0,:,:]))
axes[2].imshow(np.squeeze((recapitulated_other_protein_image_batch_tensor.cpu().clone().detach().numpy())[0,:,:]))
axes[3].imshow(np.squeeze(predicted_compartment_tensor[0,0,:,:].cpu().clone().detach().numpy()))
axes[4].imshow(np.squeeze(predicted_compartment_tensor[0,1,:,:].cpu().clone().detach().numpy()))
axes[5].imshow(np.squeeze(predicted_compartment_tensor[0,2,:,:].cpu().clone().detach().numpy()))
plt.tight_layout()

# %% [markdown]
# ### Testing the Code

# %%
# # loop over epochs
# print("[INFO] training the network...")
# startTime = time.time()
# epoch_count=1
# for e in tqdm(range(epoch_count)):
# 	# set the model in training mode
# 	unet.train()
# 	# initialize the total training and validation loss
# 	total_training_loss = 0
# 	total_validation_loss = 0
# 	# loop over the training set
# 	for (i, x) in enumerate(dataloaders["Training_Set"]):
# 		# send the input to the device
# 		npm1_image_tensor = x["npm1_image"].to(device_type)
# 		#Image needs to be reshaped into a 4D tensor. Pytorch assumes that
# 		#the first dimension is the batch size (it may become lower than the
# 		#set batch size if some values are left over). The second dimension
# 		#is the channels. This is set to one here as a dummy dimension.
# 		#Send this to the transforms section
# 		reshaped_npm1_image_tensor = npm1_image_tensor.reshape((npm1_image_tensor.shape[0], 1, image_dimensions, image_dimensions))

# 		# perform a forward pass and calculate the training loss
# 		#Compartments are predicted
# 		# print(reshaped_npm1_image_tensor.shape)
# 		predicted_compartment_tensor = unet(reshaped_npm1_image_tensor)
# 		# print(predicted_compartment_tensor.shape)
# 		#Extract predicted compartments' concentrations
# 		concentration_vector,other_protein_image_matrix,recapitulated_other_protein_image_matrix=calculate_compartment_concentrations(predicted_compartment_tensor,x["pol1_image"])
# 		# print(other_protein_image_matrix.shape)
# 		# print(recapitulated_other_protein_image_matrix.shape)
# 		print(concentration_vector)
# 		###
# 		fig,axes=plt.subplots(1,6,figsize=(20,10))
# 		axes[0].imshow(np.squeeze(x["npm1_image"].cpu().clone().detach().numpy()))
# 		axes[1].imshow(other_protein_image_matrix)
# 		axes[2].imshow(recapitulated_other_protein_image_matrix)
# 		axes[3].imshow(np.squeeze(predicted_compartment_tensor[0,0,:,:].cpu().clone().detach().numpy()))
# 		axes[4].imshow(np.squeeze(predicted_compartment_tensor[0,1,:,:].cpu().clone().detach().numpy()))
# 		axes[5].imshow(np.squeeze(predicted_compartment_tensor[0,2,:,:].cpu().clone().detach().numpy()))
# 		plt.tight_layout()

# 		if i==0:
# 			break

# %%
sample_1=list(enumerate(dataloaders["Training_Set"]))[1]

# %%
sample_1

# %%
image_dictionary=sample_1[1]
image_dictionary

# %%
sample_list

# %%
sample_list=list(enumerate(dataloaders["Validation_Set"]))

# %%
sample_list[0][1]["npm1_image"][1,:,:,:]

# %%
sample_1=sample_list[0]

image_dictionary=sample_1[1]


sample_npm1 = image_dictionary["npm1_image"].to(device_type)
sample_pol1= image_dictionary["pol1_image"].to(device_type)

reshaped_sample_npm1 = sample_npm1.reshape((sample_npm1.shape[0], 1, image_dimensions, image_dimensions))
predicted_compartment_tensor = unet(reshaped_sample_npm1)

concentration_vector,other_protein_image_matrix,recapitulated_other_protein_image_matrix=calculate_compartment_concentrations(predicted_compartment_tensor,sample_pol1)
print(concentration_vector)
  # fig,axes=plt.subplots(1,3)

  # axes[0].imshow(np.squeeze(image_dictionary["npm1_image"].cpu().clone().detach().numpy()))
  # axes[1].imshow(np.squeeze(image_dictionary["pol1_image"].cpu().clone().detach().numpy()))
  # axes[2].imshow(recapitulated_other_protein_image_matrix)
print(other_protein_image_matrix.shape)
for i in range(25):
  fig,axes=plt.subplots(1,6,figsize=(20,10))
  axes[0].imshow(np.squeeze(image_dictionary["npm1_image"][i,:,:,:].cpu().clone().detach().numpy()))
  axes[1].imshow(np.squeeze(image_dictionary["pol1_image"][i,:,:,:].cpu().clone().detach().numpy()))
  axes[2].imshow(recapitulated_other_protein_image_matrix[i,:,:].cpu().clone().detach().numpy())
  axes[3].imshow(np.squeeze(predicted_compartment_tensor[i,0,:,:].cpu().clone().detach().numpy()))
  axes[4].imshow(np.squeeze(predicted_compartment_tensor[i,1,:,:].cpu().clone().detach().numpy()))
  axes[5].imshow(np.squeeze(predicted_compartment_tensor[i,2,:,:].cpu().clone().detach().numpy()))
  plt.tight_layout()

# %%
sample_npm1 = image_dictionary["npm1_image"].to(device_type)
reshaped_sample_npm1 = sample_npm1.reshape((sample_npm1.shape[0], 1, image_dimensions, image_dimensions))
predicted_compartment_tensor = unet(reshaped_sample_npm1)
predicted_compartment_tensor

# %%
predicted_compartment_tensor.shape

# %%
print(predicted_compartment_tensor[0,:,:,:].max())
print(predicted_compartment_tensor[0,:,:,:].min())

# %%
predicted_compartment_tensor[0,:,:,:].sum()

# %%
fig,axes=plt.subplots(1,5)

axes[0].imshow(np.squeeze(predicted_compartment_tensor[0,0,:,:].cpu().clone().detach().numpy()))
axes[1].imshow(np.squeeze(predicted_compartment_tensor[0,1,:,:].cpu().clone().detach().numpy()))
axes[2].imshow(np.squeeze(predicted_compartment_tensor[0,2,:,:].cpu().clone().detach().numpy()))
axes[3].imshow(np.squeeze(image_dictionary["npm1_image"].cpu().clone().detach().numpy()))
axes[4].imshow(np.squeeze(image_dictionary["pol1_image"].cpu().clone().detach().numpy()))
